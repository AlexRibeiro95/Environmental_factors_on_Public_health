# %% [markdown]
# # Notebook for data collection and pre processing

# %% [markdown]
# #### First collecting the US cities
#
# - The data is collected from simplemaps (https://simplemaps.com/data/world-cities) which provides data for all the cities in the world.
#
# - The data is then filtered to get only the US cities.

# %%
import pandas as pd
import numpy as np

data = "https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/worldcities.csv"

df = pd.read_csv(data)

df
# Out:
#                    city        city_ascii      lat       lng  \
# 0                 Tokyo             Tokyo  35.6897  139.6922
# 1               Jakarta           Jakarta  -6.1750  106.8275
# 2                 Delhi             Delhi  28.6100   77.2300
# 3             Guangzhou         Guangzhou  23.1300  113.2600
# 4                Mumbai            Mumbai  19.0761   72.8775
# ...                 ...               ...      ...       ...
# 47863        Munha-dong        Munha-dong  39.3813  127.2517
# 47864            Sil-li            Sil-li  39.4880  125.4640
# 47865              Muan              Muan  34.9897  126.4714
# 47866         Hongseong         Hongseong  36.6009  126.6650
# 47867  Charlotte Amalie  Charlotte Amalie  18.3420  -64.9331
#
#                    country iso2 iso3      admin_name  capital  population  \
# 0                    Japan   JP  JPN           Tōkyō  primary  37732000.0
# 1                Indonesia   ID  IDN         Jakarta  primary  33756000.0
# 2                    India   IN  IND           Delhi    admin  32226000.0
# 3                    China   CN  CHN       Guangdong    admin  26940000.0
# 4                    India   IN  IND     Mahārāshtra    admin  24973000.0
# ...                    ...  ...  ...             ...      ...         ...
# 47863         Korea, North   KP  PRK         Kangwŏn      NaN         NaN
# 47864         Korea, North   KP  PRK       P’yŏngnam      NaN         NaN
# 47865         Korea, South   KR  KOR         Jeonnam    admin         NaN
# 47866         Korea, South   KR  KOR        Chungnam    admin         NaN
# 47867  U.S. Virgin Islands   VI  VIR  Virgin Islands  primary         NaN
#
#                id
# 0      1392685764
# 1      1360771077
# 2      1356872604
# 3      1156237133
# 4      1356226629
# ...           ...
# 47863  1408979215
# 47864  1408767958
# 47865  1410001061
# 47866  1410822139
# 47867  1850037473
#
# [47868 rows x 11 columns]

# %%
# Focus on entries with on the country United States

df_usa = df[df['country'] == 'United States']

df_usa
# Out:
#               city   city_ascii      lat       lng        country iso2 iso3  \
# 11        New York     New York  40.6943  -73.9249  United States   US  USA
# 33     Los Angeles  Los Angeles  34.1141 -118.4068  United States   US  USA
# 55         Chicago      Chicago  41.8375  -87.6866  United States   US  USA
# 88           Miami        Miami  25.7840  -80.2101  United States   US  USA
# 90         Houston      Houston  29.7860  -95.3885  United States   US  USA
# ...            ...          ...      ...       ...            ...  ...  ...
# 46360   Whitehouse   Whitehouse  32.2222  -95.2210  United States   US  USA
# 46378      Altoona      Altoona  44.8029  -91.4385  United States   US  USA
# 46379    Old Forge    Old Forge  41.3704  -75.7409  United States   US  USA
# 46387    West Earl    West Earl  40.1260  -76.1774  United States   US  USA
# 46440   Montpelier   Montpelier  44.2659  -72.5717  United States   US  USA
#
#          admin_name capital  population          id
# 11         New York     NaN  18908608.0  1840034016
# 33       California     NaN  11922389.0  1840020491
# 55         Illinois     NaN   8497759.0  1840000494
# 88          Florida     NaN   6080145.0  1840015149
# 90            Texas     NaN   5970127.0  1840020925
# ...             ...     ...         ...         ...
# 46360         Texas     NaN      8512.0  1840022077
# 46378     Wisconsin     NaN      8506.0  1840002295
# 46379  Pennsylvania     NaN      8506.0  1840003387
# 46387  Pennsylvania     NaN      8504.0  1840152739
# 46440       Vermont   admin      8030.0  1840002187
#
# [5324 rows x 11 columns]

# %%
# Checking missing values

df_usa.isnull().sum()
# Out:
# city             0
# city_ascii       0
# lat              0
# lng              0
# country          0
# iso2             0
# iso3             0
# admin_name       0
# capital       5273
# population       0
# id               0
# dtype: int64

# %%
# check dupplicates

df_usa.duplicated().sum()
# Out:
# 0

# %%
# drop columns

df_usa.drop(columns=['city_ascii', 'iso2', 'iso3', 'capital', 'id'], inplace=True)
# Out:
# /var/folders/9x/21kgbkbn0gx6fdwpv8lnjmnh0000gn/T/ipykernel_39374/2447420531.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_usa.drop(columns=['city_ascii', 'iso2', 'iso3', 'capital', 'id'], inplace=True)

# %%
df_usa
# Out:
#               city      lat       lng        country    admin_name  population
# 11        New York  40.6943  -73.9249  United States      New York  18908608.0
# 33     Los Angeles  34.1141 -118.4068  United States    California  11922389.0
# 55         Chicago  41.8375  -87.6866  United States      Illinois   8497759.0
# 88           Miami  25.7840  -80.2101  United States       Florida   6080145.0
# 90         Houston  29.7860  -95.3885  United States         Texas   5970127.0
# ...            ...      ...       ...            ...           ...         ...
# 46360   Whitehouse  32.2222  -95.2210  United States         Texas      8512.0
# 46378      Altoona  44.8029  -91.4385  United States     Wisconsin      8506.0
# 46379    Old Forge  41.3704  -75.7409  United States  Pennsylvania      8506.0
# 46387    West Earl  40.1260  -76.1774  United States  Pennsylvania      8504.0
# 46440   Montpelier  44.2659  -72.5717  United States       Vermont      8030.0
#
# [5324 rows x 6 columns]

# %%
# using just city and lat and lng to make a new dataframe

df_gee = df_usa[['city', 'lat', 'lng']]

# %%
df_gee
# Out:
#               city      lat       lng
# 11        New York  40.6943  -73.9249
# 33     Los Angeles  34.1141 -118.4068
# 55         Chicago  41.8375  -87.6866
# 88           Miami  25.7840  -80.2101
# 90         Houston  29.7860  -95.3885
# ...            ...      ...       ...
# 46360   Whitehouse  32.2222  -95.2210
# 46378      Altoona  44.8029  -91.4385
# 46379    Old Forge  41.3704  -75.7409
# 46387    West Earl  40.1260  -76.1774
# 46440   Montpelier  44.2659  -72.5717
#
# [5324 rows x 3 columns]

# %%
# export to csv the dataset to be used on Google Earth Engine

df_gee.to_csv('usa_cities_gee.csv', index=False)

# %% [markdown]
# ### Importing datasets obtained from Google Earth Engine
#
# - The datasets were obtained from Google Earth Engine through 5 batches of 1000 cities each.
#
# - These datasets contain the greenspaces area inside the city limits.

# %%
# Load the datasets from the uploaded files

batch_0 = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/greenspaces_gee/GreenSpaceAreas_Batch_0.csv')
batch_1000 = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/greenspaces_gee/GreenSpaceAreas_Batch_1000.csv')
batch_2000 = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/greenspaces_gee/GreenSpaceAreas_Batch_2000.csv')
batch_3000 = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/greenspaces_gee/GreenSpaceAreas_Batch_3000.csv')
batch_4000 = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/greenspaces_gee/GreenSpaceAreas_Batch_4000.csv')

# Combine the datasets into one dataframe

combined_data_new = pd.concat([batch_0, batch_1000, batch_2000, batch_3000, batch_4000])

# Check for null values in the combined new dataset

null_values_new = combined_data_new.isnull().sum()
print(null_values_new)
# Out:
# system:index         0
# city                 0
# greenSpaceArea_m2    0
# .geo                 0
# dtype: int64

# %% [markdown]
# #### Merging the Combined Data with the Original Population Data:

# %%
# Merge the original dataset with the combined green space data using both 'city' and 'admin_name' to ensure correct matching

merged_data_corrected = df_usa.merge(combined_data_new[['city', 'greenSpaceArea_m2']], on='city', how='inner')

# Remove potential duplicates by keeping the first occurrence

merged_data_corrected = merged_data_corrected.drop_duplicates(subset=['city', 'admin_name'])

# Display basic information about the merged dataset and the first few rows

merged_data_corrected.sample(5)
# Out:
#                city      lat       lng        country     admin_name  \
# 6727      Lakeville  41.8310  -70.9594  United States  Massachusetts
# 2591  Beverly Hills  34.0786 -118.4021  United States     California
# 1150         Upland  34.1178 -117.6604  United States     California
# 3671    Martha Lake  47.8479 -122.2327  United States     Washington
# 3573       Rosemont  38.5478 -121.3553  United States     California
#
#       population  greenSpaceArea_m2
# 6727     11625.0       1.138698e+03
# 2591     32406.0       5.503080e+07
# 1150     78847.0       7.053074e+07
# 3671     23259.0       3.592771e+05
# 3573     23845.0       3.280268e+07

# %%
#Convert the 'greenSpaceArea_m2' column to km2, with 2 decimal digits

merged_data_corrected['greenSpaceArea_km2'] = (merged_data_corrected['greenSpaceArea_m2'] / 1000000).round(2)

# %%
usa_df = merged_data_corrected.copy()

# Checking how many cities have green space area = 0

usa_df[usa_df['greenSpaceArea_km2'] == 0].shape

# Drop rows with green space area = 0

usa_df = usa_df[usa_df['greenSpaceArea_km2'] != 0]

# %% [markdown]
# #### Checking for cities that overlap
#
# - Eliminate cities that are less 5 km apart from each other, in order to maintain accuracy of the greenspace area.

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# Function to calculate the Haversine distance
def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0  # Earth radius in kilometers
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    
    a = np.sin(delta_phi / 2.0)**2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2.0)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    
    return R * c

# Calculate pairwise distances between all cities
def calculate_distances(df):
    coords = df[['lat', 'lng']].values
    dist_matrix = pdist(coords, metric=lambda u, v: haversine(u[0], u[1], v[0], v[1]))
    dist_matrix_square = squareform(dist_matrix)
    return pd.DataFrame(dist_matrix_square, index=df['city'], columns=df['city'])

# Calculate the distance matrix for the merged dataset
distance_matrix = calculate_distances(usa_df)

# Identify city pairs that are within a certain distance threshold (e.g., 10 km)
threshold_distance = 10  # in kilometers
close_cities = (distance_matrix < threshold_distance) & (distance_matrix > 0)

# Extract the close city pairs manually
close_cities_pairs = close_cities.stack()

# Manually create a DataFrame without reset_index
close_cities_pairs_df = pd.DataFrame({
    'City1': close_cities_pairs.index.get_level_values(0),
    'City2': close_cities_pairs.index.get_level_values(1),
    'IsClose': close_cities_pairs.values
})

# Filter out rows where cities are the same
close_cities_pairs_df = close_cities_pairs_df[close_cities_pairs_df['City1'] != close_cities_pairs_df['City2']]

# Keep only the close city pairs
close_cities_pairs_df = close_cities_pairs_df[close_cities_pairs_df['IsClose']]

# Remove duplicates where the same pair appears twice (e.g., City1-City2 and City2-City1)
close_cities_pairs_df['sorted_pair'] = close_cities_pairs_df.apply(lambda x: tuple(sorted((x['City1'], x['City2']))), axis=1)
close_cities_pairs_df = close_cities_pairs_df.drop_duplicates(subset=['sorted_pair']).drop(columns=['sorted_pair', 'IsClose'])

# Display the result
close_cities_pairs_df.sample(5)
# Out:
#               City1          City2
# 7270075    Kirkwood      Des Peres
# 12428483   Hinsdale      La Grange
# 6268919     Baldwin  East Rockaway
# 14417369    Hanover  Lake Hiawatha
# 4118624   Levittown     Burlington

# %%
import numpy as np
import pandas as pd
from scipy.spatial.distance import pdist, squareform

# Function to calculate the Haversine distance

def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0  # Earth radius in kilometers
    phi1 = np.radians(lat1)
    phi2 = np.radians(lat2)
    delta_phi = np.radians(lat2 - lat1)
    delta_lambda = np.radians(lon2 - lon1)
    
    a = np.sin(delta_phi / 2.0)**2 + np.cos(phi1) * np.cos(phi2) * np.sin(delta_lambda / 2.0)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    
    return R * c

# Calculate pairwise distances between all cities

def calculate_distances(df):
    coords = df[['lat', 'lng']].values
    dist_matrix = pdist(coords, metric=lambda u, v: haversine(u[0], u[1], v[0], v[1]))
    dist_matrix_square = squareform(dist_matrix)
    return pd.DataFrame(dist_matrix_square, index=df['city'], columns=df['city'])

# Calculate the distance matrix for the dataset

distance_matrix = calculate_distances(usa_df)

# Identify cities that have no other city within a 10 km radius

threshold_distance = 5  # in kilometers
isolation_matrix = (distance_matrix > threshold_distance) | (distance_matrix == 0)

# Identify isolated cities

isolated_cities = isolation_matrix.all(axis=1)

# Filter out the isolated cities

isolated_cities_df = usa_df[usa_df['city'].isin(isolated_cities[isolated_cities].index)]

# Display the isolated cities

print(isolated_cities_df.shape)
isolated_cities_df.head()
# Out:
# (3361, 8)
#        city      lat      lng        country admin_name  population  \
# 0  New York  40.6943 -73.9249  United States   New York  18908608.0
# 2   Chicago  41.8375 -87.6866  United States   Illinois   8497759.0
# 3     Miami  25.7840 -80.2101  United States    Florida   6080145.0
# 5   Houston  29.7860 -95.3885  United States      Texas   5970127.0
# 6    Dallas  32.7935 -96.7667  United States      Texas   5830932.0
#
#    greenSpaceArea_m2  greenSpaceArea_km2
# 0       9.581344e+06                9.58
# 2       2.852291e+05                0.29
# 3       3.557280e+07               35.57
# 5       5.257163e+07               52.57
# 6       7.990937e+07               79.91

# %%
isolated_cities_df.describe()
# Out:
#                lat          lng    population  greenSpaceArea_m2  \
# count  3361.000000  3361.000000  3.361000e+03       3.361000e+03
# mean     37.656702   -91.287030  8.555003e+04       9.931718e+07
# std       5.029581    16.065129  4.839004e+05       9.098885e+07
# min      19.582800  -159.356400  8.506000e+03       5.180484e+03
# 25%      33.884100   -97.776900  1.235600e+04       1.709698e+07
# 50%      38.791600   -87.022900  1.934900e+04       7.455334e+07
# 75%      41.434900   -79.820300  4.084200e+04       1.646949e+08
# max      48.950200   -68.716600  1.890861e+07       3.655815e+08
#
#        greenSpaceArea_km2
# count         3361.000000
# mean            99.317132
# std             90.988763
# min              0.010000
# 25%             17.100000
# 50%             74.550000
# 75%            164.690000
# max            365.580000

# %%
# Drop rows with green space area = 0

drop_rows = isolated_cities_df[isolated_cities_df['greenSpaceArea_km2'] == 0].shape

# Drop colum greenspace area m2

isolated_cities_df.drop(columns=['greenSpaceArea_m2'], inplace=True)
# Out:
# /var/folders/9x/21kgbkbn0gx6fdwpv8lnjmnh0000gn/T/ipykernel_39374/2333283045.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isolated_cities_df.drop(columns=['greenSpaceArea_m2'], inplace=True)

# %%
# Drop rows where the green space area is 0

isolated_cities_df = isolated_cities_df[isolated_cities_df['greenSpaceArea_km2'] != 0]

isolated_cities_df
# Out:
#            city      lat       lng        country    admin_name  population  \
# 0      New York  40.6943  -73.9249  United States      New York  18908608.0
# 2       Chicago  41.8375  -87.6866  United States      Illinois   8497759.0
# 3         Miami  25.7840  -80.2101  United States       Florida   6080145.0
# 5       Houston  29.7860  -95.3885  United States         Texas   5970127.0
# 6        Dallas  32.7935  -96.7667  United States         Texas   5830932.0
# ...         ...      ...       ...            ...           ...         ...
# 8544    Delavan  42.6282  -88.6323  United States     Wisconsin      8519.0
# 8545  Evergreen  48.2308 -114.2700  United States       Montana      8514.0
# 8547  Sutherlin  43.3882 -123.3242  United States        Oregon      8513.0
# 8549    Altoona  44.8029  -91.4385  United States     Wisconsin      8506.0
# 8552  Old Forge  41.3704  -75.7409  United States  Pennsylvania      8506.0
#
#       greenSpaceArea_km2
# 0                   9.58
# 2                   0.29
# 3                  35.57
# 5                  52.57
# 6                  79.91
# ...                  ...
# 8544               17.37
# 8545                0.96
# 8547               54.94
# 8549                0.27
# 8552               36.90
#
# [3361 rows x 7 columns]

# %%
isolated_cities_df.admin_name.nunique()
# Out:
# 49

# %%
# Group table by admin_name and sum the green space area and ranking by the highest green space area

isolated_cities_df_grouped = isolated_cities_df.groupby('admin_name').agg({'greenSpaceArea_km2': 'sum'}).sort_values(by='greenSpaceArea_km2', ascending=False)

isolated_cities_df_grouped
# Out:
#                       greenSpaceArea_km2
# admin_name
# Florida                         29874.81
# California                      20849.79
# North Carolina                  19473.58
# Georgia                         18281.77
# Alabama                         18168.99
# Texas                           17742.13
# Tennessee                       14013.31
# New Jersey                      13566.39
# Massachusetts                   13451.14
# Pennsylvania                    12677.75
# Missouri                        12309.14
# Ohio                            12241.42
# Virginia                        12178.02
# Maryland                         9944.01
# South Carolina                   9770.03
# Kentucky                         9704.22
# Illinois                         8941.34
# Arkansas                         8748.35
# New York                         8433.88
# Louisiana                        8321.53
# Mississippi                      6522.89
# Oklahoma                         6112.77
# Indiana                          5289.29
# Connecticut                      3457.32
# Washington                       3297.44
# Wisconsin                        3156.75
# Rhode Island                     2698.94
# Oregon                           2695.51
# Iowa                             2653.92
# Kansas                           2627.98
# New Hampshire                    2137.76
# Michigan                         1578.45
# Colorado                         1528.42
# Delaware                         1504.32
# Utah                             1502.49
# West Virginia                    1294.04
# Arizona                          1120.98
# Minnesota                        1057.08
# Hawaii                            752.26
# Vermont                           724.75
# Maine                             703.41
# Idaho                             700.24
# Nebraska                          697.01
# New Mexico                        410.68
# Nevada                            373.69
# Wyoming                           213.44
# South Dakota                      200.22
# District of Columbia               73.15
# Montana                            28.08

# %%
# How many cities do we have per admin_name

isolated_cities_df_grouped['city_count'] = isolated_cities_df['admin_name'].value_counts()

isolated_cities_df_grouped
# Out:
#                       greenSpaceArea_km2  city_count
# admin_name
# Florida                         29874.81         209
# California                      20849.79         314
# North Carolina                  19473.58          91
# Georgia                         18281.77         101
# Alabama                         18168.99          78
# Texas                           17742.13         251
# Tennessee                       14013.31          72
# New Jersey                      13566.39         112
# Massachusetts                   13451.14         148
# Pennsylvania                    12677.75         169
# Missouri                        12309.14          74
# Ohio                            12241.42         151
# Virginia                        12178.02          69
# Maryland                         9944.01          59
# South Carolina                   9770.03          60
# Kentucky                         9704.22          48
# Illinois                         8941.34         138
# Arkansas                         8748.35          42
# New York                         8433.88         143
# Louisiana                        8321.53          51
# Mississippi                      6522.89          43
# Oklahoma                         6112.77          45
# Indiana                          5289.29          68
# Connecticut                      3457.32          25
# Washington                       3297.44          88
# Wisconsin                        3156.75          83
# Rhode Island                     2698.94          25
# Oregon                           2695.51          48
# Iowa                             2653.92          40
# Kansas                           2627.98          37
# New Hampshire                    2137.76          30
# Michigan                         1578.45          40
# Colorado                         1528.42          59
# Delaware                         1504.32           9
# Utah                             1502.49          52
# West Virginia                    1294.04          14
# Arizona                          1120.98          67
# Minnesota                        1057.08          42
# Hawaii                            752.26          14
# Vermont                           724.75           7
# Maine                             703.41          23
# Idaho                             700.24          27
# Nebraska                          697.01          14
# New Mexico                        410.68          28
# Nevada                            373.69          23
# Wyoming                           213.44          10
# South Dakota                      200.22          11
# District of Columbia               73.15           1
# Montana                            28.08           8

# %% [markdown]
# ## Loading the Public Health Indicators datasets
#
# - The datasets were obtained from CDC (Centers for Disease Control and Prevention) and contain information about the public health indicators for each state in the United States (https://cdi.cdc.gov/?location=ALL&category=TOB&indicators=TOB04).

# %% [markdown]
# #### Obesity
#
# - The dataset contains information about the percentage of adults who are obese in each state in the United States.
#
# - https://www.cdc.gov/obesity/php/data-research/adult-obesity-prevalence-maps.html

# %%
# importing obesity data

obesity_data = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/health_metrics/obesity-rate-US.csv')

# %%
# Changing the column name Prevalence to obesity_rate and state to lower_case

obesity_data.rename(columns={'Prevalence': 'obesity_rate', 'State': 'state'}, inplace=True)

# Drop the column '95% CI'

obesity_data.drop(columns=['95% CI'], inplace=True)

obesity_data.head()
# Out:
#         state  obesity_rate
# 0     Alabama          38.3
# 1      Alaska          32.1
# 2     Arizona          33.2
# 3    Arkansas          37.4
# 4  California          28.1

# %% [markdown]
# #### Smoking
#
# - The datasets contain information about the percentage of adults who are obese.
#
# - https://cdi.cdc.gov/?location=ALL&category=TOB&indicators=TOB04

# %%
# importing smoking data

smoking_data = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/health_metrics/smoking-rates-us.csv')

# %%
# Maintaing only LocationDesc and DataValueDisplay columns

smoking_data = smoking_data[['LocationDesc', 'DataValueDisplay']]

# Changing column names "LocationDesc" to "state" and "DataValueDisplay" to "smoking_rate"

smoking_data.rename(columns={'LocationDesc': 'state', 'DataValueDisplay': 'smoking_rate'}, inplace=True)

smoking_data.head()
# Out:
#            state  smoking_rate
# 0  United States          13.2
# 1        Alabama          16.2
# 2         Alaska          16.2
# 3        Arizona          13.1
# 4       Arkansas          19.9

# %% [markdown]
# #### Physical Activity
#
# - Adults that follow the CDC's guidelines for physical activity, like at least 150 minutes of moderate-intensity physical activity a week, such as 30 minutes a day, 5 days a week.
#
# - https://cdi.cdc.gov/?location=ALL&category=NPAW&indicators=NPW09

# %%
# Importing Exercising data

exercising_data = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/health_metrics/phisical-exercise-us.csv')

# %%
# Maintaing only LocationDesc and DataValueDisplay columns

exercising_data = exercising_data[['LocationDesc', 'DataValueDisplay']]

# Changing column names "LocationDesc" to "state" and "DataValueDisplay" to "exercising_rate"

exercising_data.rename(columns={'LocationDesc': 'state', 'DataValueDisplay': 'exercising_rate'}, inplace=True)

exercising_data.head()
# Out:
#            state  exercising_rate
# 0  United States             51.1
# 1        Alabama             45.9
# 2         Alaska             57.4
# 3        Arizona             54.0
# 4       Arkansas             46.8

# %% [markdown]
# #### Chronic Diseases
#
# - The datasets contain information about the percentage of adults who have been diagnosed with 2 or more chronic diseases.
#
# - https://cdi.cdc.gov/?location=ALL&category=HEA&indicators=HEA05

# %%
# importing Chronic Disease data

chronic_data = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/health_metrics/chronic-diseases-us.csv')

# %%
# Maintaing only LocationDesc and DataValueDisplay columns

chronic_data = chronic_data[['LocationDesc', 'DataValueDisplay']]

# Changing column names "LocationDesc" to "state" and "DataValueDisplay" to "chronic_rate"

chronic_data.rename(columns={'LocationDesc': 'state', 'DataValueDisplay': 'chronic_rate'}, inplace=True)

chronic_data.head()
# Out:
#            state  chronic_rate
# 0  United States          17.0
# 1        Alabama          22.5
# 2         Alaska          15.1
# 3        Arizona          16.8
# 4       Arkansas          22.4

# %% [markdown]
# #### Life Expectancy
#
# - The datasets contain information about the life expectancy in each state in the United States.
#
# - https://cdi.cdc.gov/?location=ALL&category=HEA&indicators=HEA06

# %%
# importing life expectancy data

life_expectancy_data = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/health_metrics/life-expectancy-us.csv')

# %%
# Maintaing only LocationDesc and DataValueDisplay columns

life_expectancy_data = life_expectancy_data[['LocationDesc', 'DataValueDisplay']]

# Changing column names "LocationDesc" to "state" and "DataValueDisplay" to "life_expectancy"

life_expectancy_data.rename(columns={'LocationDesc': 'state', 'DataValueDisplay': 'life_expectancy'}, inplace=True)

life_expectancy_data.head()
# Out:
#            state  life_expectancy
# 0  United States             77.0
# 1        Alabama             73.2
# 2         Alaska             76.6
# 3        Arizona             76.3
# 4       Arkansas             73.8

# %% [markdown]
# #### Chronic obstructive pulmonary disease (COPD)

# %%
# importing copd data

copd_data = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/health_metrics/copd-us.csv')

# %%
# maintaing only LocationDesc and DataValueDisplay columns

copd_data = copd_data[['LocationDesc', 'DataValueDisplay']]

# Changing column names "LocationDesc" to "state" and "DataValueDisplay" to "copd_rate"

copd_data.rename(columns={'LocationDesc': 'state', 'DataValueDisplay': 'copd_rate'}, inplace=True)

copd_data.head()
# Out:
#            state  copd_rate
# 0  United States        6.1
# 1        Alabama        8.3
# 2         Alaska        5.4
# 3        Arizona        5.9
# 4       Arkansas        8.9

# %% [markdown]
# #### Depression rates

# %%
# importing depression data

depression_data = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/health_metrics/depression-us.csv')

# %%
# maintaing only LocationDesc and DataValueDisplay columns

depression_data = depression_data[['LocationDesc', 'DataValueDisplay']]

# Changing column names "LocationDesc" to "state" and "DataValueDisplay" to "depression_rate"

depression_data.rename(columns={'LocationDesc': 'state', 'DataValueDisplay': 'depression_rate'}, inplace=True)

depression_data.head()
# Out:
#            state  depression_rate
# 0  United States             21.1
# 1        Alabama             24.6
# 2         Alaska             20.4
# 3        Arizona             20.6
# 4       Arkansas             27.6

# %% [markdown]
# ##### Merge the main dataset with the public health indicators datasets

# %%
# df_usa lower case columns and change admin_name to state

isolated_cities_df.columns = isolated_cities_df.columns.str.lower()

isolated_cities_df.rename(columns={'admin_name': 'state'}, inplace=True)

isolated_cities_df
# Out:
#            city      lat       lng        country         state  population  \
# 0      New York  40.6943  -73.9249  United States      New York  18908608.0
# 2       Chicago  41.8375  -87.6866  United States      Illinois   8497759.0
# 3         Miami  25.7840  -80.2101  United States       Florida   6080145.0
# 5       Houston  29.7860  -95.3885  United States         Texas   5970127.0
# 6        Dallas  32.7935  -96.7667  United States         Texas   5830932.0
# ...         ...      ...       ...            ...           ...         ...
# 8544    Delavan  42.6282  -88.6323  United States     Wisconsin      8519.0
# 8545  Evergreen  48.2308 -114.2700  United States       Montana      8514.0
# 8547  Sutherlin  43.3882 -123.3242  United States        Oregon      8513.0
# 8549    Altoona  44.8029  -91.4385  United States     Wisconsin      8506.0
# 8552  Old Forge  41.3704  -75.7409  United States  Pennsylvania      8506.0
#
#       greenspacearea_km2
# 0                   9.58
# 2                   0.29
# 3                  35.57
# 5                  52.57
# 6                  79.91
# ...                  ...
# 8544               17.37
# 8545                0.96
# 8547               54.94
# 8549                0.27
# 8552               36.90
#
# [3361 rows x 7 columns]

# %%
# Adding the 5 datasets to the isolated_cities_df

isolated_cities_df = isolated_cities_df.merge(obesity_data, on='state', how='left')
isolated_cities_df = isolated_cities_df.merge(smoking_data, on='state', how='left')
isolated_cities_df = isolated_cities_df.merge(exercising_data, on='state', how='left')
isolated_cities_df = isolated_cities_df.merge(chronic_data, on='state', how='left')
isolated_cities_df = isolated_cities_df.merge(life_expectancy_data, on='state', how='left')
isolated_cities_df = isolated_cities_df.merge(copd_data, on='state', how='left')
isolated_cities_df = isolated_cities_df.merge(depression_data, on='state', how='left')


isolated_cities_df
# Out:
#            city      lat       lng        country         state  population  \
# 0      New York  40.6943  -73.9249  United States      New York  18908608.0
# 1       Chicago  41.8375  -87.6866  United States      Illinois   8497759.0
# 2         Miami  25.7840  -80.2101  United States       Florida   6080145.0
# 3       Houston  29.7860  -95.3885  United States         Texas   5970127.0
# 4        Dallas  32.7935  -96.7667  United States         Texas   5830932.0
# ...         ...      ...       ...            ...           ...         ...
# 3356    Delavan  42.6282  -88.6323  United States     Wisconsin      8519.0
# 3357  Evergreen  48.2308 -114.2700  United States       Montana      8514.0
# 3358  Sutherlin  43.3882 -123.3242  United States        Oregon      8513.0
# 3359    Altoona  44.8029  -91.4385  United States     Wisconsin      8506.0
# 3360  Old Forge  41.3704  -75.7409  United States  Pennsylvania      8506.0
#
#       greenspacearea_km2  obesity_rate  smoking_rate  exercising_rate  \
# 0                   9.58          30.1          11.5             50.7
# 1                   0.29          33.4          12.8             50.0
# 2                  35.57          31.6          12.0             54.3
# 3                  52.57          35.5          12.0             49.4
# 4                  79.91          35.5          12.0             49.4
# ...                  ...           ...           ...              ...
# 3356               17.37          37.7          15.0             55.0
# 3357                0.96          30.5          16.0             63.2
# 3358               54.94          30.9          12.8             56.8
# 3359                0.27          37.7          15.0             55.0
# 3360               36.90          33.4          15.6             50.8
#
#       chronic_rate  life_expectancy  copd_rate  depression_rate
# 0             15.7             77.7        4.6             18.1
# 1             15.6             76.8        5.2             18.0
# 2             16.5             77.5        6.2             18.3
# 3             16.6             76.5        5.6             19.4
# 4             16.6             76.5        5.6             19.4
# ...            ...              ...        ...              ...
# 3356          17.0             77.7        5.8             24.2
# 3357          16.4             76.8        5.7             25.8
# 3358          17.4             78.8        5.8             24.8
# 3359          17.0             77.7        5.8             24.2
# 3360          18.5             76.8        6.6             22.3
#
# [3361 rows x 14 columns]

# %%
# replace exercising rate missing values with the mean

isolated_cities_df['exercising_rate'] = isolated_cities_df['exercising_rate'].fillna(isolated_cities_df['exercising_rate'].mean())

# %%
isolated_cities_df.shape
# Out:
# (3361, 14)

# %%
isolated_cities_df.dtypes
# Out:
# city                   object
# lat                   float64
# lng                   float64
# country                object
# state                  object
# population            float64
# greenspacearea_km2    float64
# obesity_rate          float64
# smoking_rate          float64
# exercising_rate       float64
# chronic_rate          float64
# life_expectancy       float64
# copd_rate             float64
# depression_rate       float64
# dtype: object

# %%
# importing state population to incorporate in the analysis

state_population = pd.read_csv('https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/state_population.csv')

# lower columns name

state_population.columns = state_population.columns.str.lower()

# %%
# merging isolated_cities_df with state_population on state with a new column called state_population

merged_final_df = isolated_cities_df.merge(state_population, on='state', how='left')

# %%
# changing District of Columbia to Washington on the state column

merged_final_df['state'] = merged_final_df['state'].replace('District of Columbia', 'Washington')

# Swap the values between population_x (city) and population_y (state) for row 4

merged_final_df.loc[4, ['population_x', 'population_y']] = merged_final_df.loc[4, ['population_y', 'population_x']].values

# %%
merged_final_df
# Out:
#            city      lat       lng        country         state  population_x  \
# 0      New York  40.6943  -73.9249  United States      New York    18908608.0
# 1       Chicago  41.8375  -87.6866  United States      Illinois     8497759.0
# 2         Miami  25.7840  -80.2101  United States       Florida     6080145.0
# 3       Houston  29.7860  -95.3885  United States         Texas     5970127.0
# 4        Dallas  32.7935  -96.7667  United States         Texas    30503301.0
# ...         ...      ...       ...            ...           ...           ...
# 3356    Delavan  42.6282  -88.6323  United States     Wisconsin        8519.0
# 3357  Evergreen  48.2308 -114.2700  United States       Montana        8514.0
# 3358  Sutherlin  43.3882 -123.3242  United States        Oregon        8513.0
# 3359    Altoona  44.8029  -91.4385  United States     Wisconsin        8506.0
# 3360  Old Forge  41.3704  -75.7409  United States  Pennsylvania        8506.0
#
#       greenspacearea_km2  obesity_rate  smoking_rate  exercising_rate  \
# 0                   9.58          30.1          11.5             50.7
# 1                   0.29          33.4          12.8             50.0
# 2                  35.57          31.6          12.0             54.3
# 3                  52.57          35.5          12.0             49.4
# 4                  79.91          35.5          12.0             49.4
# ...                  ...           ...           ...              ...
# 3356               17.37          37.7          15.0             55.0
# 3357                0.96          30.5          16.0             63.2
# 3358               54.94          30.9          12.8             56.8
# 3359                0.27          37.7          15.0             55.0
# 3360               36.90          33.4          15.6             50.8
#
#       chronic_rate  life_expectancy  copd_rate  depression_rate  population_y
# 0             15.7             77.7        4.6             18.1      19571216
# 1             15.6             76.8        5.2             18.0      12549689
# 2             16.5             77.5        6.2             18.3      22610726
# 3             16.6             76.5        5.6             19.4      30503301
# 4             16.6             76.5        5.6             19.4       5830932
# ...            ...              ...        ...              ...           ...
# 3356          17.0             77.7        5.8             24.2       5910955
# 3357          16.4             76.8        5.7             25.8       1132812
# 3358          17.4             78.8        5.8             24.8       4233358
# 3359          17.0             77.7        5.8             24.2       5910955
# 3360          18.5             76.8        6.6             22.3      12961683
#
# [3361 rows x 15 columns]

# %%
# Function to switch the population values if the city population is greater than the state population

def switch_population_if_needed(df, city_col='population_x', state_col='population_y'):
    """
    This function checks if the population of a city is greater than the population of its state
    and switches them if necessary.
    
    Parameters:
    - df: DataFrame containing the population data.
    - city_col: Name of the column representing the city population.
    - state_col: Name of the column representing the state population.
    
    Returns:
    - The updated DataFrame with corrected population values.
    """
    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        # Check if the city population is greater than the state population
        if row[city_col] > row[state_col]:
            # Switch the population values
            df.at[index, city_col], df.at[index, state_col] = row[state_col], row[city_col]
    
    return df

# Apply the function to your dataset

merged_final_df = switch_population_if_needed(merged_final_df, city_col='population_x', state_col='population_y')

# %%
# how many rows we have with population_x bigger than population_y

merged_final_df[merged_final_df['population_x'] > merged_final_df['population_y']].shape
# Out:
# (0, 22)

# %% [markdown]
# ### Calculating the health factors to a city level

# %%
# Step 1: Calculate the population weight for each city

merged_final_df['population_weight'] = merged_final_df['population_x'] / merged_final_df['population_y']

# Step 2: Adjust the state-level metrics to estimate city-level metrics

merged_final_df['adjusted_obesity_rate'] = merged_final_df['obesity_rate'] * merged_final_df['population_weight']
merged_final_df['adjusted_smoking_rate'] = merged_final_df['smoking_rate'] * merged_final_df['population_weight']
merged_final_df['adjusted_exercising_rate'] = merged_final_df['exercising_rate'] * merged_final_df['population_weight']
merged_final_df['adjusted_chronic_rate'] = merged_final_df['chronic_rate'] * merged_final_df['population_weight']
merged_final_df['adjusted_life_expectancy'] = merged_final_df['life_expectancy'] * merged_final_df['population_weight']
merged_final_df['adjusted_copd_rate'] = merged_final_df['copd_rate'] * merged_final_df['population_weight']
merged_final_df['adjusted_depression_rate'] = merged_final_df['depression_rate'] * merged_final_df['population_weight']

# Step 3: (Optional) Clean up the dataset by dropping unnecessary columns

merged_final_df.drop(columns=['population_weight'], inplace=True)

# Step 4: Review the first few rows to ensure everything looks correct

print(merged_final_df[['city', 'state', 'adjusted_obesity_rate', 'adjusted_smoking_rate', 'adjusted_exercising_rate', 'adjusted_chronic_rate', 'adjusted_life_expectancy']].head())

# Save the adjusted dataset if needed

merged_final_df.to_csv('adjusted_city_level_metrics.csv', index=False)
# Out:
#        city     state  adjusted_obesity_rate  adjusted_smoking_rate  \
# 0  New York  New York              29.080927              11.110653
# 1   Chicago  Illinois              22.616110               8.667252
# 2     Miami   Florida               8.497409               3.226864
# 3   Houston     Texas               6.948084               2.348648
# 4    Dallas     Texas             185.710824              62.775490
#
#    adjusted_exercising_rate  adjusted_chronic_rate  adjusted_life_expectancy
# 0                 48.983488              15.168457                 75.069369
# 1                 33.856453              10.563213                 52.003511
# 2                 14.601560               4.436938                 20.840164
# 3                  9.668602               3.248963                 14.972632
# 4                258.425766              86.839427                400.193747

# %%
merged_final_df
# Out:
#            city      lat       lng        country         state  population_x  \
# 0      New York  40.6943  -73.9249  United States      New York    18908608.0
# 1       Chicago  41.8375  -87.6866  United States      Illinois     8497759.0
# 2         Miami  25.7840  -80.2101  United States       Florida     6080145.0
# 3       Houston  29.7860  -95.3885  United States         Texas     5970127.0
# 4        Dallas  32.7935  -96.7667  United States         Texas    30503301.0
# ...         ...      ...       ...            ...           ...           ...
# 3356    Delavan  42.6282  -88.6323  United States     Wisconsin        8519.0
# 3357  Evergreen  48.2308 -114.2700  United States       Montana        8514.0
# 3358  Sutherlin  43.3882 -123.3242  United States        Oregon        8513.0
# 3359    Altoona  44.8029  -91.4385  United States     Wisconsin        8506.0
# 3360  Old Forge  41.3704  -75.7409  United States  Pennsylvania        8506.0
#
#       greenspacearea_km2  obesity_rate  smoking_rate  exercising_rate  ...  \
# 0                   9.58          30.1          11.5             50.7  ...
# 1                   0.29          33.4          12.8             50.0  ...
# 2                  35.57          31.6          12.0             54.3  ...
# 3                  52.57          35.5          12.0             49.4  ...
# 4                  79.91          35.5          12.0             49.4  ...
# ...                  ...           ...           ...              ...  ...
# 3356               17.37          37.7          15.0             55.0  ...
# 3357                0.96          30.5          16.0             63.2  ...
# 3358               54.94          30.9          12.8             56.8  ...
# 3359                0.27          37.7          15.0             55.0  ...
# 3360               36.90          33.4          15.6             50.8  ...
#
#       copd_rate  depression_rate  population_y  adjusted_obesity_rate  \
# 0           4.6             18.1      19571216              29.080927
# 1           5.2             18.0      12549689              22.616110
# 2           6.2             18.3      22610726               8.497409
# 3           5.6             19.4      30503301               6.948084
# 4           5.6             19.4       5830932             185.710824
# ...         ...              ...           ...                    ...
# 3356        5.8             24.2       5910955               0.054334
# 3357        5.7             25.8       1132812               0.229232
# 3358        5.8             24.8       4233358               0.062138
# 3359        5.8             24.2       5910955               0.054251
# 3360        6.6             22.3      12961683               0.021918
#
#       adjusted_smoking_rate  adjusted_exercising_rate  adjusted_chronic_rate  \
# 0                 11.110653                 48.983488              15.168457
# 1                  8.667252                 33.856453              10.563213
# 2                  3.226864                 14.601560               4.436938
# 3                  2.348648                  9.668602               3.248963
# 4                 62.775490                258.425766              86.839427
# ...                     ...                       ...                    ...
# 3356               0.021618                  0.079267               0.024501
# 3357               0.120253                  0.474999               0.123259
# 3358               0.025740                  0.114221               0.034990
# 3359               0.021585                  0.079146               0.024463
# 3360               0.010237                  0.033337               0.012140
#
#       adjusted_life_expectancy  adjusted_copd_rate  adjusted_depression_rate
# 0                    75.069369            4.444261                 17.487202
# 1                    52.003511            3.521071                 12.188323
# 2                    20.840164            1.667213                  4.920968
# 3                    14.972632            1.096036                  3.796981
# 4                   400.193747           29.295229                101.487042
# ...                        ...                 ...                       ...
# 3356                  0.111983            0.008359                  0.034878
# 3357                  0.577214            0.042840                  0.193908
# 3358                  0.158462            0.011663                  0.049871
# 3359                  0.111812            0.008346                  0.034824
# 3360                  0.050399            0.004331                  0.014634
#
# [3361 rows x 22 columns]

# %%
# Organizing final dataset for analysis

# Rename population columns for clarity (optional)

merged_final_df.rename(columns={'population_x': 'population_city', 'population_y': 'population_state'}, inplace=True)

# Keep only the necessary columns

columns_to_keep = [
    'city', 'state', 'country', 'greenspacearea_km2', 'adjusted_obesity_rate',
    'adjusted_smoking_rate', 'adjusted_exercising_rate',
    'adjusted_chronic_rate', 'adjusted_life_expectancy',    
    'adjusted_copd_rate', 'adjusted_depression_rate',
    'population_city', 'population_state',
]

dataset = merged_final_df[columns_to_keep]

# %%
dataset
# Out:
#            city         state        country  greenspacearea_km2  \
# 0      New York      New York  United States                9.58
# 1       Chicago      Illinois  United States                0.29
# 2         Miami       Florida  United States               35.57
# 3       Houston         Texas  United States               52.57
# 4        Dallas         Texas  United States               79.91
# ...         ...           ...            ...                 ...
# 3356    Delavan     Wisconsin  United States               17.37
# 3357  Evergreen       Montana  United States                0.96
# 3358  Sutherlin        Oregon  United States               54.94
# 3359    Altoona     Wisconsin  United States                0.27
# 3360  Old Forge  Pennsylvania  United States               36.90
#
#       adjusted_obesity_rate  adjusted_smoking_rate  adjusted_exercising_rate  \
# 0                 29.080927              11.110653                 48.983488
# 1                 22.616110               8.667252                 33.856453
# 2                  8.497409               3.226864                 14.601560
# 3                  6.948084               2.348648                  9.668602
# 4                  6.786088               2.293889                  9.443176
# ...                     ...                    ...                       ...
# 3356               0.054334               0.021618                  0.079267
# 3357               0.229232               0.120253                  0.474999
# 3358               0.062138               0.025740                  0.114221
# 3359               0.054251               0.021585                  0.079146
# 3360               0.021918               0.010237                  0.033337
#
#       adjusted_chronic_rate  adjusted_life_expectancy  adjusted_copd_rate  \
# 0                 15.168457                 75.069369            4.444261
# 1                 10.563213                 52.003511            3.521071
# 2                  4.436938                 20.840164            1.667213
# 3                  3.248963                 14.972632            1.096036
# 4                  3.173213                 14.623542            1.070481
# ...                     ...                       ...                 ...
# 3356               0.024501                  0.111983            0.008359
# 3357               0.123259                  0.577214            0.042840
# 3358               0.034990                  0.158462            0.011663
# 3359               0.024463                  0.111812            0.008346
# 3360               0.012140                  0.050399            0.004331
#
#       adjusted_depression_rate  population_city  population_state
# 0                    17.487202       18908608.0          19571216
# 1                    12.188323        8497759.0          12549689
# 2                     4.920968        6080145.0          22610726
# 3                     3.796981        5970127.0          30503301
# 4                     3.708454        5830932.0          30503301
# ...                        ...              ...               ...
# 3356                  0.034878           8519.0           5910955
# 3357                  0.193908           8514.0           1132812
# 3358                  0.049871           8513.0           4233358
# 3359                  0.034824           8506.0           5910955
# 3360                  0.014634           8506.0          12961683
#
# [3361 rows x 13 columns]

# %% [markdown]
# #### Adding Air Pollution data
#
# - https://openweathermap.org/api/air-pollution

# %%
import requests

# Your OpenWeatherMap API key
api_key = "d41a752677c4a9ef823b1d88695c910f"

# Example coordinates for a city (New York City in this case)
lat, lon = 40.7128, -74.0060  # Latitude and Longitude for New York City

# Start and end Unix timestamps for the year 2022
start = 1640995200  # January 1, 2022
end = 1672531199    # December 31, 2022

# API endpoint with the specified start and end dates
url = f"http://api.openweathermap.org/data/2.5/air_pollution/history?lat={lat}&lon={lon}&start={start}&end={end}&appid={api_key}"

# Make the API request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    # Process and analyze the data as needed
    data
else:
    print(f"Failed to retrieve data: {response.status_code}")

data
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7128},
#  'list': [{'main': {'aqi': 4},
#    'components': {'co': 1028.06,
#     'no': 101.03,
#     'no2': 50.72,
#     'o3': 0,
#     'so2': 10.97,
#     'pm2_5': 37.37,
#     'pm10': 48.12,
#     'nh3': 4.5},
#    'dt': 1640995200},
#   {'main': {'aqi': 4},
#    'components': {'co': 1201.63,
#     'no': 125.17,
#     'no2': 51.41,
#     'o3': 0,
#     'so2': 9.3,
#     'pm2_5': 48.57,
#     'pm10': 61.74,
#     'nh3': 5.38},
#    'dt': 1640998800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1415.25,
#     'no': 153.78,
#     'no2': 51.41,
#     'o3': 0,
#     'so2': 7.99,
#     'pm2_5': 63.8,
#     'pm10': 79.29,
#     'nh3': 6.02},
#    'dt': 1641002400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1562.12,
#     'no': 175.24,
#     'no2': 50.72,
#     'o3': 0,
#     'so2': 7.39,
#     'pm2_5': 75.18,
#     'pm10': 92.05,
#     'nh3': 6.52},
#    'dt': 1641006000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1588.82,
#     'no': 177.03,
#     'no2': 49.35,
#     'o3': 0,
#     'so2': 7.39,
#     'pm2_5': 76.89,
#     'pm10': 92.59,
#     'nh3': 6.27},
#    'dt': 1641009600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1401.9,
#     'no': 150.2,
#     'no2': 46.61,
#     'o3': 0,
#     'so2': 8.11,
#     'pm2_5': 65.8,
#     'pm10': 77.1,
#     'nh3': 4.5},
#    'dt': 1641013200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1161.58,
#     'no': 112.65,
#     'no2': 45.24,
#     'o3': 0,
#     'so2': 9.18,
#     'pm2_5': 51.33,
#     'pm10': 59.05,
#     'nh3': 3.2},
#    'dt': 1641016800},
#   {'main': {'aqi': 4},
#    'components': {'co': 907.9,
#     'no': 74.21,
#     'no2': 45.24,
#     'o3': 0,
#     'so2': 10.85,
#     'pm2_5': 36,
#     'pm10': 41.07,
#     'nh3': 2.28},
#    'dt': 1641020400},
#   {'main': {'aqi': 4},
#    'components': {'co': 754.36,
#     'no': 50.07,
#     'no2': 45.24,
#     'o3': 0,
#     'so2': 10.73,
#     'pm2_5': 26.32,
#     'pm10': 30.02,
#     'nh3': 1.69},
#    'dt': 1641024000},
#   {'main': {'aqi': 3},
#    'components': {'co': 647.54,
#     'no': 32.19,
#     'no2': 44.55,
#     'o3': 0,
#     'so2': 9.89,
#     'pm2_5': 20.85,
#     'pm10': 23.93,
#     'nh3': 1.44},
#    'dt': 1641027600},
#   {'main': {'aqi': 2},
#    'components': {'co': 560.76,
#     'no': 20.79,
#     'no2': 42.16,
#     'o3': 0.03,
#     'so2': 9.42,
#     'pm2_5': 16.76,
#     'pm10': 19.36,
#     'nh3': 1.3},
#    'dt': 1641031200},
#   {'main': {'aqi': 2},
#    'components': {'co': 527.38,
#     'no': 19.22,
#     'no2': 40.44,
#     'o3': 0.05,
#     'so2': 9.54,
#     'pm2_5': 15.48,
#     'pm10': 17.91,
#     'nh3': 1.46},
#    'dt': 1641034800},
#   {'main': {'aqi': 3},
#    'components': {'co': 620.84,
#     'no': 34.42,
#     'no2': 42.5,
#     'o3': 0,
#     'so2': 9.66,
#     'pm2_5': 20.18,
#     'pm10': 23.61,
#     'nh3': 2.44},
#    'dt': 1641038400},
#   {'main': {'aqi': 4},
#    'components': {'co': 767.71,
#     'no': 56.33,
#     'no2': 47.98,
#     'o3': 0.01,
#     'so2': 10.01,
#     'pm2_5': 26.84,
#     'pm10': 31.44,
#     'nh3': 3.39},
#    'dt': 1641042000},
#   {'main': {'aqi': 4},
#    'components': {'co': 807.76,
#     'no': 66.16,
#     'no2': 48.67,
#     'o3': 0.19,
#     'so2': 10.13,
#     'pm2_5': 28.08,
#     'pm10': 33.03,
#     'nh3': 3.36},
#    'dt': 1641045600},
#   {'main': {'aqi': 3},
#    'components': {'co': 747.68,
#     'no': 61.69,
#     'no2': 44.55,
#     'o3': 0.85,
#     'so2': 10.73,
#     'pm2_5': 24.67,
#     'pm10': 29.37,
#     'nh3': 2.79},
#    'dt': 1641049200},
#   {'main': {'aqi': 3},
#    'components': {'co': 667.57,
#     'no': 50.96,
#     'no2': 37.01,
#     'o3': 1.97,
#     'so2': 10.73,
#     'pm2_5': 20.79,
#     'pm10': 25.14,
#     'nh3': 2.31},
#    'dt': 1641052800},
#   {'main': {'aqi': 2},
#    'components': {'co': 640.87,
#     'no': 47.83,
#     'no2': 32.22,
#     'o3': 2.01,
#     'so2': 11.92,
#     'pm2_5': 19.95,
#     'pm10': 24.24,
#     'nh3': 2.31},
#    'dt': 1641056400},
#   {'main': {'aqi': 3},
#    'components': {'co': 640.87,
#     'no': 50.51,
#     'no2': 30.85,
#     'o3': 1.74,
#     'so2': 14.19,
#     'pm2_5': 20.74,
#     'pm10': 24.91,
#     'nh3': 2.44},
#    'dt': 1641060000},
#   {'main': {'aqi': 4},
#    'components': {'co': 801.09,
#     'no': 76.89,
#     'no2': 29.82,
#     'o3': 0.66,
#     'so2': 12.52,
#     'pm2_5': 28.61,
#     'pm10': 34.11,
#     'nh3': 3.17},
#    'dt': 1641063600},
#   {'main': {'aqi': 4},
#    'components': {'co': 1148.22,
#     'no': 132.32,
#     'no2': 29.82,
#     'o3': 0.19,
#     'so2': 11.09,
#     'pm2_5': 45.41,
#     'pm10': 53.12,
#     'nh3': 4.31},
#    'dt': 1641067200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1548.77,
#     'no': 198.48,
#     'no2': 33.24,
#     'o3': 0.04,
#     'so2': 11.92,
#     'pm2_5': 66.61,
#     'pm10': 75.6,
#     'nh3': 5.51},
#    'dt': 1641070800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1976.01,
#     'no': 275.37,
#     'no2': 40.44,
#     'o3': 0,
#     'so2': 13.71,
#     'pm2_5': 89.45,
#     'pm10': 98.94,
#     'nh3': 6.14},
#    'dt': 1641074400},
#   {'main': {'aqi': 5},
#    'components': {'co': 2189.64,
#     'no': 318.29,
#     'no2': 45.93,
#     'o3': 0,
#     'so2': 15.02,
#     'pm2_5': 101.33,
#     'pm10': 109.93,
#     'nh3': 5.38},
#    'dt': 1641078000},
#   {'main': {'aqi': 5},
#    'components': {'co': 2162.93,
#     'no': 314.71,
#     'no2': 48.67,
#     'o3': 0,
#     'so2': 16.21,
#     'pm2_5': 100.67,
#     'pm10': 108.47,
#     'nh3': 4.75},
#    'dt': 1641081600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1895.9,
#     'no': 264.64,
#     'no2': 47.3,
#     'o3': 0,
#     'so2': 14.07,
#     'pm2_5': 85.24,
#     'pm10': 92.08,
#     'nh3': 4.05},
#    'dt': 1641085200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1615.52,
#     'no': 212.79,
#     'no2': 41.13,
#     'o3': 0,
#     'so2': 9.66,
#     'pm2_5': 69.38,
#     'pm10': 75.41,
#     'nh3': 3.32},
#    'dt': 1641088800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1361.85,
#     'no': 168.09,
#     'no2': 35.3,
#     'o3': 0,
#     'so2': 6.85,
#     'pm2_5': 54.26,
#     'pm10': 59.04,
#     'nh3': 2.69},
#    'dt': 1641092400},
#   {'main': {'aqi': 4},
#    'components': {'co': 961.3,
#     'no': 101.03,
#     'no2': 34.96,
#     'o3': 0,
#     'so2': 7.21,
#     'pm2_5': 33.28,
#     'pm10': 36.23,
#     'nh3': 1.69},
#    'dt': 1641096000},
#   {'main': {'aqi': 3},
#    'components': {'co': 801.09,
#     'no': 71.53,
#     'no2': 35.3,
#     'o3': 0,
#     'so2': 6.2,
#     'pm2_5': 24.13,
#     'pm10': 26.38,
#     'nh3': 1.04},
#    'dt': 1641099600},
#   {'main': {'aqi': 2},
#    'components': {'co': 700.95,
#     'no': 53.64,
#     'no2': 35.64,
#     'o3': 0,
#     'so2': 5.42,
#     'pm2_5': 19.48,
#     'pm10': 21.31,
#     'nh3': 0.78},
#    'dt': 1641103200},
#   {'main': {'aqi': 2},
#    'components': {'co': 654.22,
#     'no': 43.81,
#     'no2': 35.64,
#     'o3': 0,
#     'so2': 5.13,
#     'pm2_5': 17.73,
#     'pm10': 19.48,
#     'nh3': 0.74},
#    'dt': 1641106800},
#   {'main': {'aqi': 2},
#    'components': {'co': 654.22,
#     'no': 45.15,
#     'no2': 34.62,
#     'o3': 0,
#     'so2': 5.25,
#     'pm2_5': 18.33,
#     'pm10': 20.06,
#     'nh3': 0.74},
#    'dt': 1641110400},
#   {'main': {'aqi': 3},
#    'components': {'co': 680.92,
#     'no': 51.86,
#     'no2': 32.22,
#     'o3': 0,
#     'so2': 5.01,
#     'pm2_5': 20.03,
#     'pm10': 21.63,
#     'nh3': 0.69},
#    'dt': 1641114000},
#   {'main': {'aqi': 3},
#    'components': {'co': 741,
#     'no': 65.27,
#     'no2': 26.73,
#     'o3': 0,
#     'so2': 2.98,
#     'pm2_5': 24.61,
#     'pm10': 26.95,
#     'nh3': 0.89},
#    'dt': 1641117600},
#   {'main': {'aqi': 4},
#    'components': {'co': 841.14,
#     'no': 86.72,
#     'no2': 21.59,
#     'o3': 0,
#     'so2': 2.62,
#     'pm2_5': 32.43,
#     'pm10': 36.16,
#     'nh3': 1.55},
#    'dt': 1641121200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1201.63,
#     'no': 148.42,
#     'no2': 22.62,
#     'o3': 0,
#     'so2': 3.31,
#     'pm2_5': 55.48,
#     'pm10': 63.39,
#     'nh3': 4.56},
#    'dt': 1641124800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1842.5,
#     'no': 257.49,
#     'no2': 29.47,
#     'o3': 0,
#     'so2': 4.23,
#     'pm2_5': 93.19,
#     'pm10': 106.69,
#     'nh3': 8.11},
#    'dt': 1641128400},
#   {'main': {'aqi': 5},
#    'components': {'co': 2243.04,
#     'no': 332.59,
#     'no2': 32.22,
#     'o3': 0.06,
#     'so2': 3.87,
#     'pm2_5': 115.51,
#     'pm10': 131.58,
#     'nh3': 6.97},
#    'dt': 1641132000},
#   {'main': {'aqi': 5},
#    'components': {'co': 2189.64,
#     'no': 329.02,
#     'no2': 28.1,
#     'o3': 0.2,
#     'so2': 3.67,
#     'pm2_5': 108.5,
#     'pm10': 123.87,
#     'nh3': 4.88},
#    'dt': 1641135600},
#   {'main': {'aqi': 4},
#    'components': {'co': 761.03,
#     'no': 76,
#     'no2': 22.62,
#     'o3': 1.1,
#     'so2': 8.34,
#     'pm2_5': 25.19,
#     'pm10': 31.01,
#     'nh3': 1.96},
#    'dt': 1641139200},
#   {'main': {'aqi': 2},
#    'components': {'co': 594.14,
#     'no': 42.92,
#     'no2': 22.62,
#     'o3': 2.12,
#     'so2': 7.63,
#     'pm2_5': 15.82,
#     'pm10': 21.82,
#     'nh3': 1.74},
#    'dt': 1641142800},
#   {'main': {'aqi': 2},
#    'components': {'co': 487.33,
#     'no': 25.93,
#     'no2': 21.08,
#     'o3': 2.77,
#     'so2': 7.09,
#     'pm2_5': 11.67,
#     'pm10': 16.44,
#     'nh3': 1.5},
#    'dt': 1641146400},
#   {'main': {'aqi': 1},
#    'components': {'co': 403.88,
#     'no': 12.41,
#     'no2': 19.71,
#     'o3': 2.44,
#     'so2': 6.14,
#     'pm2_5': 8.8,
#     'pm10': 11.3,
#     'nh3': 0.85},
#    'dt': 1641150000},
#   {'main': {'aqi': 1},
#    'components': {'co': 407.22,
#     'no': 11.18,
#     'no2': 20.91,
#     'o3': 1.63,
#     'so2': 6.14,
#     'pm2_5': 7.85,
#     'pm10': 9.98,
#     'nh3': 0.93},
#    'dt': 1641153600},
#   {'main': {'aqi': 1},
#    'components': {'co': 447.27,
#     'no': 11.85,
#     'no2': 22.96,
#     'o3': 0.66,
#     'so2': 5.54,
#     'pm2_5': 6.67,
#     'pm10': 8.8,
#     'nh3': 1.23},
#    'dt': 1641157200},
#   {'main': {'aqi': 1},
#    'components': {'co': 487.33,
#     'no': 10.62,
#     'no2': 25.7,
#     'o3': 0.35,
#     'so2': 4.59,
#     'pm2_5': 5.71,
#     'pm10': 7.66,
#     'nh3': 1.35},
#    'dt': 1641160800},
#   {'main': {'aqi': 1},
#    'components': {'co': 473.98,
#     'no': 6.2,
#     'no2': 28.1,
#     'o3': 1.81,
#     'so2': 3.76,
#     'pm2_5': 4.46,
#     'pm10': 6.11,
#     'nh3': 1.28},
#    'dt': 1641164400},
#   {'main': {'aqi': 1},
#    'components': {'co': 417.23,
#     'no': 1.62,
#     'no2': 26.05,
#     'o3': 10.73,
#     'so2': 3.16,
#     'pm2_5': 3.26,
#     'pm10': 4.75,
#     'nh3': 1.2},
#    'dt': 1641168000},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 0.37,
#     'no2': 22.28,
#     'o3': 22.35,
#     'so2': 2.86,
#     'pm2_5': 2.8,
#     'pm10': 4.26,
#     'nh3': 1.17},
#    'dt': 1641171600},
#   {'main': {'aqi': 1},
#    'components': {'co': 377.18,
#     'no': 0.27,
#     'no2': 22.28,
#     'o3': 25.39,
#     'so2': 2.92,
#     'pm2_5': 2.93,
#     'pm10': 4.49,
#     'nh3': 1.27},
#    'dt': 1641175200},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.23,
#     'no2': 22.28,
#     'o3': 27.89,
#     'so2': 2.92,
#     'pm2_5': 3.02,
#     'pm10': 4.68,
#     'nh3': 1.36},
#    'dt': 1641178800},
#   {'main': {'aqi': 1},
#    'components': {'co': 363.83,
#     'no': 0.14,
#     'no2': 21.42,
#     'o3': 31.83,
#     'so2': 3.07,
#     'pm2_5': 2.74,
#     'pm10': 4.31,
#     'nh3': 1.31},
#    'dt': 1641182400},
#   {'main': {'aqi': 1},
#    'components': {'co': 337.12,
#     'no': 0.04,
#     'no2': 16.96,
#     'o3': 39.7,
#     'so2': 3.13,
#     'pm2_5': 1.77,
#     'pm10': 2.94,
#     'nh3': 0.99},
#    'dt': 1641186000},
#   {'main': {'aqi': 1},
#    'components': {'co': 330.45,
#     'no': 0.04,
#     'no2': 17.31,
#     'o3': 43.63,
#     'so2': 3.81,
#     'pm2_5': 1.77,
#     'pm10': 2.94,
#     'nh3': 1.04},
#    'dt': 1641189600},
#   {'main': {'aqi': 1},
#    'components': {'co': 323.77,
#     'no': 0.02,
#     'no2': 16.62,
#     'o3': 49.35,
#     'so2': 4.17,
#     'pm2_5': 1.75,
#     'pm10': 2.96,
#     'nh3': 1.06},
#    'dt': 1641193200},
#   {'main': {'aqi': 1},
#    'components': {'co': 317.1,
#     'no': 0.01,
#     'no2': 16.11,
#     'o3': 54.36,
#     'so2': 4.47,
#     'pm2_5': 1.69,
#     'pm10': 2.87,
#     'nh3': 1.08},
#    'dt': 1641196800},
#   {'main': {'aqi': 1},
#    'components': {'co': 313.76,
#     'no': 0.01,
#     'no2': 15.77,
#     'o3': 57.22,
#     'so2': 4.95,
#     'pm2_5': 1.6,
#     'pm10': 2.75,
#     'nh3': 1.09},
#    'dt': 1641200400},
#   {'main': {'aqi': 1},
#    'components': {'co': 310.42,
#     'no': 0.01,
#     'no2': 15.08,
#     'o3': 58.65,
#     'so2': 5.25,
#     'pm2_5': 1.47,
#     'pm10': 2.55,
#     'nh3': 1.08},
#    'dt': 1641204000},
#   {'main': {'aqi': 1},
#    'components': {'co': 310.42,
#     'no': 0.01,
#     'no2': 15.59,
#     'o3': 59.37,
#     'so2': 5.42,
#     'pm2_5': 1.63,
#     'pm10': 2.77,
#     'nh3': 1.14},
#    'dt': 1641207600},
#   {'main': {'aqi': 1},
#    'components': {'co': 330.45,
#     'no': 0.02,
#     'no2': 20.91,
#     'o3': 57.94,
#     'so2': 5.42,
#     'pm2_5': 2.78,
#     'pm10': 4.42,
#     'nh3': 1.57},
#    'dt': 1641211200},
#   {'main': {'aqi': 1},
#    'components': {'co': 353.81,
#     'no': 0.05,
#     'no2': 26.39,
#     'o3': 53.64,
#     'so2': 5.96,
#     'pm2_5': 3.71,
#     'pm10': 5.84,
#     'nh3': 1.95},
#    'dt': 1641214800},
#   {'main': {'aqi': 1},
#    'components': {'co': 363.83,
#     'no': 0.26,
#     'no2': 29.13,
#     'o3': 50.07,
#     'so2': 6.44,
#     'pm2_5': 4,
#     'pm10': 6.33,
#     'nh3': 2.09},
#    'dt': 1641218400},
#   {'main': {'aqi': 1},
#    'components': {'co': 367.16,
#     'no': 0.83,
#     'no2': 29.82,
#     'o3': 48.64,
#     'so2': 6.91,
#     'pm2_5': 4.08,
#     'pm10': 6.47,
#     'nh3': 2.12},
#    'dt': 1641222000},
#   {'main': {'aqi': 1},
#    'components': {'co': 363.83,
#     'no': 1.49,
#     'no2': 29.13,
#     'o3': 48.64,
#     'so2': 7.51,
#     'pm2_5': 3.88,
#     'pm10': 5.86,
#     'nh3': 1.88},
#    'dt': 1641225600},
#   {'main': {'aqi': 1},
#    'components': {'co': 353.81,
#     'no': 1.7,
#     'no2': 27.08,
#     'o3': 51.5,
#     'so2': 7.45,
#     'pm2_5': 3.37,
#     'pm10': 5.02,
#     'nh3': 1.6},
#    'dt': 1641229200},
#   {'main': {'aqi': 1},
#    'components': {'co': 343.8,
#     'no': 1.58,
#     'no2': 25.36,
#     'o3': 53.64,
#     'so2': 6.97,
#     'pm2_5': 2.97,
#     'pm10': 4.4,
#     'nh3': 1.38},
#    'dt': 1641232800},
#   {'main': {'aqi': 1},
#    'components': {'co': 337.12,
#     'no': 1.33,
#     'no2': 24.33,
#     'o3': 55.07,
#     'so2': 6.5,
#     'pm2_5': 2.74,
#     'pm10': 4.05,
#     'nh3': 1.27},
#    'dt': 1641236400},
#   {'main': {'aqi': 1},
#    'components': {'co': 333.79,
#     'no': 0.82,
#     'no2': 24.68,
#     'o3': 55.07,
#     'so2': 6.14,
#     'pm2_5': 2.67,
#     'pm10': 3.91,
#     'nh3': 1.22},
#    'dt': 1641240000},
#   {'main': {'aqi': 1},
#    'components': {'co': 327.11,
#     'no': 0.27,
#     'no2': 24.33,
#     'o3': 57.22,
#     'so2': 5.36,
#     'pm2_5': 2.57,
#     'pm10': 3.7,
#     'nh3': 1.16},
#    'dt': 1641243600},
#   {'main': {'aqi': 1},
#    'components': {'co': 330.45,
#     'no': 0.03,
#     'no2': 23.99,
#     'o3': 60.08,
#     'so2': 4.77,
#     'pm2_5': 2.53,
#     'pm10': 3.78,
#     'nh3': 1.23},
#    'dt': 1641247200},
#   {'main': {'aqi': 1},
#    'components': {'co': 340.46,
#     'no': 0.03,
#     'no2': 26.39,
#     'o3': 57.94,
#     'so2': 4.71,
#     'pm2_5': 2.99,
#     'pm10': 4.52,
#     'nh3': 1.49},
#    'dt': 1641250800},
#   {'main': {'aqi': 1},
#    'components': {'co': 353.81,
#     'no': 0.04,
#     'no2': 28.79,
#     'o3': 54.36,
#     'so2': 4.59,
#     'pm2_5': 3.84,
#     'pm10': 5.76,
#     'nh3': 1.79},
#    'dt': 1641254400},
#   {'main': {'aqi': 1},
#    'components': {'co': 367.16,
#     'no': 0.07,
#     'no2': 30.5,
#     'o3': 48.64,
#     'so2': 4.53,
#     'pm2_5': 4.75,
#     'pm10': 7.08,
#     'nh3': 2.06},
#    'dt': 1641258000},
#   {'main': {'aqi': 1},
#    'components': {'co': 370.5,
#     'no': 0.1,
#     'no2': 30.85,
#     'o3': 44.35,
#     'so2': 4.41,
#     'pm2_5': 5.26,
#     'pm10': 7.79,
#     'nh3': 2.18},
#    'dt': 1641261600},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 0.13,
#     'no2': 31.19,
#     'o3': 42.56,
#     'so2': 4.29,
#     'pm2_5': 5.78,
#     'pm10': 8.52,
#     'nh3': 2.37},
#    'dt': 1641265200},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.08,
#     'no2': 28.45,
#     'o3': 46.49,
#     'so2': 4.23,
#     'pm2_5': 5.15,
#     'pm10': 7.71,
#     'nh3': 2.22},
#    'dt': 1641268800},
#   {'main': {'aqi': 1},
#    'components': {'co': 337.12,
#     'no': 0.02,
#     'no2': 20.05,
#     'o3': 58.65,
#     'so2': 3.99,
#     'pm2_5': 3.05,
#     'pm10': 4.78,
#     'nh3': 1.55},
#    'dt': 1641272400},
#   {'main': {'aqi': 1},
#    'components': {'co': 317.1,
#     'no': 0.01,
#     'no2': 15.94,
#     'o3': 66.52,
#     'so2': 3.78,
#     'pm2_5': 2.21,
#     'pm10': 3.49,
#     'nh3': 1.27},
#    'dt': 1641276000},
#   {'main': {'aqi': 1},
#    'components': {'co': 310.42,
#     'no': 0.01,
#     'no2': 14.22,
#     'o3': 70.1,
#     'so2': 3.73,
#     'pm2_5': 1.97,
#     'pm10': 3.12,
#     'nh3': 1.16},
#    'dt': 1641279600},
#   {'main': {'aqi': 1},
#    'components': {'co': 313.76,
#     'no': 0.01,
#     'no2': 15.08,
#     'o3': 69.38,
#     'so2': 4.17,
#     'pm2_5': 2.14,
#     'pm10': 3.35,
#     'nh3': 1.2},
#    'dt': 1641283200},
#   {'main': {'aqi': 1},
#    'components': {'co': 317.1,
#     'no': 0.01,
#     'no2': 16.96,
#     'o3': 66.52,
#     'so2': 4.83,
#     'pm2_5': 2.46,
#     'pm10': 3.8,
#     'nh3': 1.31},
#    'dt': 1641286800},
#   {'main': {'aqi': 1},
#    'components': {'co': 320.43,
#     'no': 0.01,
#     'no2': 18.68,
#     'o3': 63.66,
#     'so2': 5.36,
#     'pm2_5': 2.78,
#     'pm10': 4.27,
#     'nh3': 1.41},
#    'dt': 1641290400},
#   {'main': {'aqi': 1},
#    'components': {'co': 337.12,
#     'no': 0.03,
#     'no2': 23.65,
#     'o3': 55.79,
#     'so2': 6.14,
#     'pm2_5': 3.72,
#     'pm10': 5.57,
#     'nh3': 1.73},
#    'dt': 1641294000},
#   {'main': {'aqi': 2},
#    'components': {'co': 407.22,
#     'no': 0.41,
#     'no2': 40.78,
#     'o3': 35.05,
#     'so2': 7.09,
#     'pm2_5': 7.67,
#     'pm10': 10.84,
#     'nh3': 3.01},
#    'dt': 1641297600},
#   {'main': {'aqi': 2},
#    'components': {'co': 494,
#     'no': 3.69,
#     'no2': 58.95,
#     'o3': 12.87,
#     'so2': 8.82,
#     'pm2_5': 11.99,
#     'pm10': 16.65,
#     'nh3': 4.43},
#    'dt': 1641301200},
#   {'main': {'aqi': 2},
#    'components': {'co': 540.73,
#     'no': 15.42,
#     'no2': 55.52,
#     'o3': 14.84,
#     'so2': 11.44,
#     'pm2_5': 14.01,
#     'pm10': 19.48,
#     'nh3': 5.26},
#    'dt': 1641304800},
#   {'main': {'aqi': 2},
#    'components': {'co': 554.08,
#     'no': 25.03,
#     'no2': 49.35,
#     'o3': 24.68,
#     'so2': 14.78,
#     'pm2_5': 15.12,
#     'pm10': 20.94,
#     'nh3': 5.57},
#    'dt': 1641308400},
#   {'main': {'aqi': 2},
#    'components': {'co': 554.08,
#     'no': 29.95,
#     'no2': 50.04,
#     'o3': 32.19,
#     'so2': 18.36,
#     'pm2_5': 16.24,
#     'pm10': 21.95,
#     'nh3': 5.64},
#    'dt': 1641312000},
#   {'main': {'aqi': 3},
#    'components': {'co': 587.46,
#     'no': 37.1,
#     'no2': 56.89,
#     'o3': 33.26,
#     'so2': 24.32,
#     'pm2_5': 20.23,
#     'pm10': 26.22,
#     'nh3': 6.08},
#    'dt': 1641315600},
#   {'main': {'aqi': 4},
#    'components': {'co': 640.87,
#     'no': 43.36,
#     'no2': 66.49,
#     'o3': 32.9,
#     'so2': 30.52,
#     'pm2_5': 25.17,
#     'pm10': 31.46,
#     'nh3': 6.4},
#    'dt': 1641319200},
#   {'main': {'aqi': 4},
#    'components': {'co': 694.27,
#     'no': 48.73,
#     'no2': 77.46,
#     'o3': 29.68,
#     'so2': 32.9,
#     'pm2_5': 29.82,
#     'pm10': 36.98,
#     'nh3': 6.78},
#    'dt': 1641322800},
#   {'main': {'aqi': 4},
#    'components': {'co': 747.68,
#     'no': 56.77,
#     'no2': 89.11,
#     'o3': 21.1,
#     'so2': 32.9,
#     'pm2_5': 32.8,
#     'pm10': 41.76,
#     'nh3': 7.41},
#    'dt': 1641326400},
#   {'main': {'aqi': 4},
#    'components': {'co': 761.03,
#     'no': 54.99,
#     'no2': 95.96,
#     'o3': 9.92,
#     'so2': 26.94,
#     'pm2_5': 30.74,
#     'pm10': 40.4,
#     'nh3': 7.16},
#    'dt': 1641330000},
#   {'main': {'aqi': 4},
#    'components': {'co': 754.36,
#     'no': 47.39,
#     'no2': 97.33,
#     'o3': 0.91,
#     'so2': 22.41,
#     'pm2_5': 27.58,
#     'pm10': 36.78,
#     'nh3': 7.22},
#    'dt': 1641333600},
#   {'main': {'aqi': 3},
#    'components': {'co': 720.98,
#     'no': 38.89,
#     'no2': 90.48,
#     'o3': 0,
#     'so2': 19.55,
#     'pm2_5': 23.95,
#     'pm10': 32.22,
#     'nh3': 7.03},
#    'dt': 1641337200},
#   {'main': {'aqi': 3},
#    'components': {'co': 700.95,
#     'no': 33.08,
#     'no2': 87.05,
#     'o3': 0.01,
#     'so2': 16.93,
#     'pm2_5': 22.89,
#     'pm10': 31.16,
#     'nh3': 6.71},
#    'dt': 1641340800},
#   {'main': {'aqi': 3},
#    'components': {'co': 707.63,
#     'no': 29.95,
#     'no2': 86.37,
#     'o3': 0.02,
#     'so2': 15.5,
#     'pm2_5': 24.93,
#     'pm10': 33.43,
#     'nh3': 6.84},
#    'dt': 1641344400},
#   {'main': {'aqi': 4},
#    'components': {'co': 707.63,
#     'no': 26.6,
#     'no2': 85,
#     'o3': 0.06,
#     'so2': 14.78,
#     'pm2_5': 27.78,
#     'pm10': 36.16,
#     'nh3': 6.84},
#    'dt': 1641348000},
#   {'main': {'aqi': 4},
#    'components': {'co': 700.95,
#     'no': 23.92,
#     'no2': 83.63,
#     'o3': 0.1,
#     'so2': 14.31,
#     'pm2_5': 30.19,
#     'pm10': 38.69,
#     'nh3': 6.65},
#    'dt': 1641351600},
#   {'main': {'aqi': 4},
#    'components': {'co': 640.87,
#     'no': 15.42,
#     'no2': 80.88,
#     'o3': 0.66,
#     'so2': 13.47,
#     'pm2_5': 28.26,
#     'pm10': 35.82,
#     'nh3': 5.57},
#    'dt': 1641355200},
#   {'main': {'aqi': 2},
#    'components': {'co': 507.35,
#     'no': 2.57,
#     'no2': 66.49,
#     'o3': 11.44,
#     'so2': 12.04,
#     'pm2_5': 19.44,
#     'pm10': 24.5,
#     'nh3': 3.45},
#    'dt': 1641358800},
#   {'main': {'aqi': 2},
#    'components': {'co': 417.23,
#     'no': 0.11,
#     'no2': 45.24,
#     'o3': 37.55,
#     'so2': 10.85,
#     'pm2_5': 12.87,
#     'pm10': 16.07,
#     'nh3': 2.18},
#    'dt': 1641362400},
#   {'main': {'aqi': 2},
#    'components': {'co': 387.19,
#     'no': 0.03,
#     'no2': 37.7,
#     'o3': 49.35,
#     'so2': 10.25,
#     'pm2_5': 10.77,
#     'pm10': 13.33,
#     'nh3': 1.77},
#    'dt': 1641366000},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.04,
#     'no2': 41.47,
#     'o3': 45.06,
#     'so2': 10.49,
#     'pm2_5': 11.75,
#     'pm10': 14.56,
#     'nh3': 1.93},
#    'dt': 1641369600},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.89,
#     'no': 0.1,
#     'no2': 46.61,
#     'o3': 37.55,
#     'so2': 11.09,
#     'pm2_5': 12.74,
#     'pm10': 15.92,
#     'nh3': 2.15},
#    'dt': 1641373200},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 0.25,
#     'no2': 52.78,
#     'o3': 28.25,
#     'so2': 11.92,
#     'pm2_5': 13.59,
#     'pm10': 17.27,
#     'nh3': 2.37},
#    'dt': 1641376800},
#   {'main': {'aqi': 2},
#    'components': {'co': 460.62,
#     'no': 0.89,
#     'no2': 61.01,
#     'o3': 17.88,
#     'so2': 12.87,
#     'pm2_5': 14.95,
#     'pm10': 19.47,
#     'nh3': 2.88},
#    'dt': 1641380400},
#   {'main': {'aqi': 3},
#    'components': {'co': 580.79,
#     'no': 11.51,
#     'no2': 75.4,
#     'o3': 2.46,
#     'so2': 12.76,
#     'pm2_5': 21.41,
#     'pm10': 28.26,
#     'nh3': 4.05},
#    'dt': 1641384000},
#   {'main': {'aqi': 4},
#    'components': {'co': 747.68,
#     'no': 38,
#     'no2': 82.94,
#     'o3': 0.03,
#     'so2': 11.92,
#     'pm2_5': 29.84,
#     'pm10': 38.74,
#     'nh3': 4.18},
#    'dt': 1641387600},
#   {'main': {'aqi': 4},
#    'components': {'co': 854.49,
#     'no': 53.2,
#     'no2': 91.85,
#     'o3': 0.21,
#     'so2': 12.28,
#     'pm2_5': 34.21,
#     'pm10': 43.88,
#     'nh3': 4.31},
#    'dt': 1641391200},
#   {'main': {'aqi': 4},
#    'components': {'co': 854.49,
#     'no': 52.3,
#     'no2': 93.22,
#     'o3': 0.87,
#     'so2': 12.64,
#     'pm2_5': 33.62,
#     'pm10': 43.25,
#     'nh3': 4.12},
#    'dt': 1641394800},
#   {'main': {'aqi': 4},
#    'components': {'co': 747.68,
#     'no': 39.34,
#     'no2': 83.63,
#     'o3': 2.35,
#     'so2': 12.76,
#     'pm2_5': 27,
#     'pm10': 35.85,
#     'nh3': 3.64},
#    'dt': 1641398400},
#   {'main': {'aqi': 2},
#    'components': {'co': 634.19,
#     'no': 27.49,
#     'no2': 71.97,
#     'o3': 3.98,
#     'so2': 12.87,
#     'pm2_5': 19.77,
#     'pm10': 27.41,
#     'nh3': 3.13},
#    'dt': 1641402000},
#   {'main': {'aqi': 2},
#    'components': {'co': 527.38,
#     'no': 15.87,
#     'no2': 61.69,
#     'o3': 8.67,
#     'so2': 12.28,
#     'pm2_5': 13.3,
#     'pm10': 19.39,
#     'nh3': 2.63},
#    'dt': 1641405600},
#   {'main': {'aqi': 2},
#    'components': {'co': 390.53,
#     'no': 3.35,
#     'no2': 45.24,
#     'o3': 30.76,
#     'so2': 8.82,
#     'pm2_5': 7,
#     'pm10': 11.53,
#     'nh3': 1.66},
#    'dt': 1641409200},
#   {'main': {'aqi': 2},
#    'components': {'co': 367.16,
#     'no': 1.44,
#     'no2': 41.47,
#     'o3': 37.55,
#     'so2': 8.46,
#     'pm2_5': 6.25,
#     'pm10': 11.13,
#     'nh3': 1.5},
#    'dt': 1641412800},
#   {'main': {'aqi': 2},
#    'components': {'co': 367.16,
#     'no': 0.58,
#     'no2': 42.84,
#     'o3': 36.84,
#     'so2': 8.46,
#     'pm2_5': 6.32,
#     'pm10': 11.28,
#     'nh3': 1.52},
#    'dt': 1641416400},
#   {'main': {'aqi': 2},
#    'components': {'co': 397.21,
#     'no': 0.38,
#     'no2': 50.72,
#     'o3': 27.89,
#     'so2': 9.06,
#     'pm2_5': 7.61,
#     'pm10': 12.91,
#     'nh3': 1.69},
#    'dt': 1641420000},
#   {'main': {'aqi': 2},
#    'components': {'co': 453.95,
#     'no': 1.7,
#     'no2': 63.75,
#     'o3': 13.41,
#     'so2': 9.78,
#     'pm2_5': 10.26,
#     'pm10': 16.33,
#     'nh3': 1.93},
#    'dt': 1641423600},
#   {'main': {'aqi': 2},
#    'components': {'co': 507.35,
#     'no': 5.81,
#     'no2': 70.6,
#     'o3': 4.25,
#     'so2': 10.01,
#     'pm2_5': 13.87,
#     'pm10': 20.96,
#     'nh3': 2.18},
#    'dt': 1641427200},
#   {'main': {'aqi': 3},
#    'components': {'co': 607.49,
#     'no': 18.78,
#     'no2': 74.03,
#     'o3': 0.45,
#     'so2': 9.54,
#     'pm2_5': 20.63,
#     'pm10': 29.51,
#     'nh3': 2.69},
#    'dt': 1641430800},
#   {'main': {'aqi': 4},
#    'components': {'co': 707.63,
#     'no': 31.74,
#     'no2': 77.46,
#     'o3': 0.01,
#     'so2': 8.34,
#     'pm2_5': 27.67,
#     'pm10': 38.45,
#     'nh3': 2.88},
#    'dt': 1641434400},
#   {'main': {'aqi': 4},
#    'components': {'co': 767.71,
#     'no': 38.44,
#     'no2': 79.51,
#     'o3': 0,
#     'so2': 7.21,
#     'pm2_5': 32.84,
#     'pm10': 45.02,
#     'nh3': 2.91},
#    'dt': 1641438000},
#   {'main': {'aqi': 4},
#    'components': {'co': 761.03,
#     'no': 35.76,
#     'no2': 77.46,
#     'o3': 0,
#     'so2': 6.44,
#     'pm2_5': 32.85,
#     'pm10': 44.89,
#     'nh3': 2.44},
#    'dt': 1641441600},
#   {'main': {'aqi': 4},
#    'components': {'co': 640.87,
#     'no': 20.56,
#     'no2': 71.29,
#     'o3': 0.05,
#     'so2': 5.9,
#     'pm2_5': 25.73,
#     'pm10': 35.44,
#     'nh3': 1.36},
#    'dt': 1641445200},
#   {'main': {'aqi': 3},
#    'components': {'co': 540.73,
#     'no': 9.28,
#     'no2': 61.69,
#     'o3': 0.83,
#     'so2': 5.72,
#     'pm2_5': 20.56,
#     'pm10': 28.04,
#     'nh3': 0.93},
#    'dt': 1641448800},
#   {'main': {'aqi': 2},
#    'components': {'co': 473.98,
#     'no': 2.65,
#     'no2': 52.09,
#     'o3': 5.99,
#     'so2': 5.42,
#     'pm2_5': 17.98,
#     'pm10': 23.88,
#     'nh3': 0.7},
#    'dt': 1641452400},
#   {'main': {'aqi': 2},
#    'components': {'co': 440.6,
#     'no': 0.8,
#     'no2': 44.55,
#     'o3': 14.13,
#     'so2': 5.25,
#     'pm2_5': 17.69,
#     'pm10': 22.71,
#     'nh3': 0.62},
#    'dt': 1641456000},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 0.33,
#     'no2': 40.78,
#     'o3': 21.64,
#     'so2': 5.66,
#     'pm2_5': 17.85,
#     'pm10': 22.35,
#     'nh3': 0.6},
#    'dt': 1641459600},
#   {'main': {'aqi': 2},
#    'components': {'co': 393.87,
#     'no': 0.08,
#     'no2': 30.85,
#     'o3': 35.76,
#     'so2': 6.14,
#     'pm2_5': 13.45,
#     'pm10': 16.85,
#     'nh3': 0.61},
#    'dt': 1641463200},
#   {'main': {'aqi': 1},
#    'components': {'co': 353.81,
#     'no': 0.03,
#     'no2': 25.7,
#     'o3': 46.49,
#     'so2': 7.27,
#     'pm2_5': 8.65,
#     'pm10': 11.06,
#     'nh3': 0.82},
#    'dt': 1641466800},
#   {'main': {'aqi': 1},
#    'components': {'co': 377.18,
#     'no': 0.08,
#     'no2': 31.87,
#     'o3': 41.84,
#     'so2': 8.11,
#     'pm2_5': 8.74,
#     'pm10': 11.39,
#     'nh3': 1.6},
#    'dt': 1641470400},
#   {'main': {'aqi': 1},
#    'components': {'co': 387.19,
#     'no': 0.15,
#     'no2': 33.59,
#     'o3': 39.7,
#     'so2': 7.75,
#     'pm2_5': 8.08,
#     'pm10': 10.65,
#     'nh3': 2.06},
#    'dt': 1641474000},
#   {'main': {'aqi': 1},
#    'components': {'co': 400.54,
#     'no': 1.75,
#     'no2': 32.56,
#     'o3': 39.34,
#     'so2': 7.63,
#     'pm2_5': 7.14,
#     'pm10': 9.73,
#     'nh3': 2.22},
#    'dt': 1641477600},
#   {'main': {'aqi': 1},
#    'components': {'co': 397.21,
#     'no': 4.75,
#     'no2': 26.05,
#     'o3': 45.78,
#     'so2': 7.63,
#     'pm2_5': 6.25,
#     'pm10': 8.8,
#     'nh3': 2.12},
#    'dt': 1641481200},
#   {'main': {'aqi': 1},
#    'components': {'co': 387.19,
#     'no': 6.31,
#     'no2': 21.25,
#     'o3': 50.07,
#     'so2': 7.75,
#     'pm2_5': 5.31,
#     'pm10': 7.65,
#     'nh3': 1.92},
#    'dt': 1641484800},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 6.82,
#     'no2': 19.02,
#     'o3': 52.21,
#     'so2': 7.99,
#     'pm2_5': 4.6,
#     'pm10': 6.73,
#     'nh3': 1.73},
#    'dt': 1641488400},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 6.71,
#     'no2': 17.99,
#     'o3': 52.93,
#     'so2': 7.99,
#     'pm2_5': 4.15,
#     'pm10': 6.13,
#     'nh3': 1.6},
#    'dt': 1641492000},
#   {'main': {'aqi': 1},
#    'components': {'co': 420.57,
#     'no': 10.51,
#     'no2': 26.73,
#     'o3': 43.27,
#     'so2': 9.66,
#     'pm2_5': 6.24,
#     'pm10': 9.04,
#     'nh3': 2.31},
#    'dt': 1641495600},
#   {'main': {'aqi': 2},
#    'components': {'co': 507.35,
#     'no': 17.43,
#     'no2': 42.84,
#     'o3': 26.82,
#     'so2': 11.8,
#     'pm2_5': 10.09,
#     'pm10': 14.57,
#     'nh3': 3.48},
#    'dt': 1641499200},
#   {'main': {'aqi': 2},
#    'components': {'co': 587.46,
#     'no': 22.35,
#     'no2': 58.95,
#     'o3': 9.83,
#     'so2': 13.23,
#     'pm2_5': 13.19,
#     'pm10': 19.19,
#     'nh3': 4.5},
#    'dt': 1641502800},
#   {'main': {'aqi': 3},
#    'components': {'co': 754.36,
#     'no': 45.15,
#     'no2': 71.97,
#     'o3': 0.26,
#     'so2': 12.4,
#     'pm2_5': 20.41,
#     'pm10': 29.02,
#     'nh3': 6.4},
#    'dt': 1641506400},
#   {'main': {'aqi': 4},
#    'components': {'co': 988.01,
#     'no': 80.47,
#     'no2': 77.46,
#     'o3': 0,
#     'so2': 10.37,
#     'pm2_5': 31.34,
#     'pm10': 43.22,
#     'nh3': 8.74},
#    'dt': 1641510000},
#   {'main': {'aqi': 4},
#    'components': {'co': 1161.58,
#     'no': 106.39,
#     'no2': 75.4,
#     'o3': 0,
#     'so2': 9.54,
#     'pm2_5': 42.4,
#     'pm10': 57.54,
#     'nh3': 10.89},
#    'dt': 1641513600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1361.85,
#     'no': 134.11,
#     'no2': 74.03,
#     'o3': 0,
#     'so2': 10.85,
#     'pm2_5': 57.39,
#     'pm10': 76.71,
#     'nh3': 15.07},
#    'dt': 1641517200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1495.36,
#     'no': 151.99,
#     'no2': 73.34,
#     'o3': 0,
#     'so2': 10.61,
#     'pm2_5': 68.99,
#     'pm10': 92.51,
#     'nh3': 17.48},
#    'dt': 1641520800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1548.77,
#     'no': 153.78,
#     'no2': 73.34,
#     'o3': 0,
#     'so2': 9.54,
#     'pm2_5': 74.37,
#     'pm10': 101.61,
#     'nh3': 17.73},
#    'dt': 1641524400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1522.06,
#     'no': 144.84,
#     'no2': 72.66,
#     'o3': 0,
#     'so2': 9.42,
#     'pm2_5': 72.49,
#     'pm10': 97.87,
#     'nh3': 15.58},
#    'dt': 1641528000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1361.85,
#     'no': 116.23,
#     'no2': 70.6,
#     'o3': 0,
#     'so2': 10.13,
#     'pm2_5': 59.05,
#     'pm10': 76.98,
#     'nh3': 10.89},
#    'dt': 1641531600},
#   {'main': {'aqi': 4},
#    'components': {'co': 1081.47,
#     'no': 70.63,
#     'no2': 67.17,
#     'o3': 0,
#     'so2': 9.89,
#     'pm2_5': 39.14,
#     'pm10': 49.62,
#     'nh3': 6.59},
#    'dt': 1641535200},
#   {'main': {'aqi': 2},
#    'components': {'co': 487.33,
#     'no': 3.97,
#     'no2': 43.53,
#     'o3': 9.39,
#     'so2': 9.54,
#     'pm2_5': 9.08,
#     'pm10': 11.52,
#     'nh3': 1.68},
#    'dt': 1641538800},
#   {'main': {'aqi': 1},
#    'components': {'co': 393.87,
#     'no': 0.29,
#     'no2': 28.1,
#     'o3': 25.03,
#     'so2': 9.42,
#     'pm2_5': 5.27,
#     'pm10': 6.6,
#     'nh3': 1.11},
#    'dt': 1641542400},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 0.19,
#     'no2': 25.7,
#     'o3': 29.33,
#     'so2': 8.94,
#     'pm2_5': 4.43,
#     'pm10': 5.64,
#     'nh3': 1.06},
#    'dt': 1641546000},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.17,
#     'no2': 24.68,
#     'o3': 31.47,
#     'so2': 8.46,
#     'pm2_5': 3.69,
#     'pm10': 4.87,
#     'nh3': 1.03},
#    'dt': 1641549600},
#   {'main': {'aqi': 1},
#    'components': {'co': 377.18,
#     'no': 0.24,
#     'no2': 25.7,
#     'o3': 29.68,
#     'so2': 8.34,
#     'pm2_5': 3.65,
#     'pm10': 4.93,
#     'nh3': 1.19},
#    'dt': 1641553200},
#   {'main': {'aqi': 1},
#    'components': {'co': 413.89,
#     'no': 1.1,
#     'no2': 33.93,
#     'o3': 18.78,
#     'so2': 8.23,
#     'pm2_5': 5.62,
#     'pm10': 7.57,
#     'nh3': 1.84},
#    'dt': 1641556800},
#   {'main': {'aqi': 2},
#    'components': {'co': 460.62,
#     'no': 4.36,
#     'no2': 42.16,
#     'o3': 7.69,
#     'so2': 9.18,
#     'pm2_5': 7.73,
#     'pm10': 10.35,
#     'nh3': 2.5},
#    'dt': 1641560400},
#   {'main': {'aqi': 1},
#    'components': {'co': 473.98,
#     'no': 10.39,
#     'no2': 39.07,
#     'o3': 9.57,
#     'so2': 9.3,
#     'pm2_5': 8.44,
#     'pm10': 11.35,
#     'nh3': 2.66},
#    'dt': 1641564000},
#   {'main': {'aqi': 1},
#    'components': {'co': 460.62,
#     'no': 14.53,
#     'no2': 29.82,
#     'o3': 21.82,
#     'so2': 8.58,
#     'pm2_5': 8.11,
#     'pm10': 11.08,
#     'nh3': 2.5},
#    'dt': 1641567600},
#   {'main': {'aqi': 1},
#    'components': {'co': 423.91,
#     'no': 12.29,
#     'no2': 21.76,
#     'o3': 33.26,
#     'so2': 7.51,
#     'pm2_5': 6.12,
#     'pm10': 8.86,
#     'nh3': 2.22},
#    'dt': 1641571200},
#   {'main': {'aqi': 1},
#    'components': {'co': 390.53,
#     'no': 9.16,
#     'no2': 17.31,
#     'o3': 37.19,
#     'so2': 6.38,
#     'pm2_5': 4.17,
#     'pm10': 6.38,
#     'nh3': 1.73},
#    'dt': 1641574800},
#   {'main': {'aqi': 1},
#    'components': {'co': 370.5,
#     'no': 6.93,
#     'no2': 15.42,
#     'o3': 40.05,
#     'so2': 5.25,
#     'pm2_5': 3.06,
#     'pm10': 4.77,
#     'nh3': 1.33},
#    'dt': 1641578400},
#   {'main': {'aqi': 1},
#    'components': {'co': 357.15,
#     'no': 5.98,
#     'no2': 15.08,
#     'o3': 41.48,
#     'so2': 5.78,
#     'pm2_5': 2.53,
#     'pm10': 4.02,
#     'nh3': 1.17},
#    'dt': 1641582000},
#   {'main': {'aqi': 1},
#    'components': {'co': 360.49,
#     'no': 5.81,
#     'no2': 17.65,
#     'o3': 38.98,
#     'so2': 7.33,
#     'pm2_5': 2.65,
#     'pm10': 4.16,
#     'nh3': 1.22},
#    'dt': 1641585600},
#   {'main': {'aqi': 1},
#    'components': {'co': 367.16,
#     'no': 3.97,
#     'no2': 22.62,
#     'o3': 32.9,
#     'so2': 7.99,
#     'pm2_5': 2.71,
#     'pm10': 4.3,
#     'nh3': 1.35},
#    'dt': 1641589200},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 0.96,
#     'no2': 29.47,
#     'o3': 25.75,
#     'so2': 7.87,
#     'pm2_5': 2.7,
#     'pm10': 4.31,
#     'nh3': 1.46},
#    'dt': 1641592800},
#   {'main': {'aqi': 1},
#    'components': {'co': 383.85,
#     'no': 0.54,
#     'no2': 31.53,
#     'o3': 24.32,
#     'so2': 7.99,
#     'pm2_5': 2.98,
#     'pm10': 4.7,
#     'nh3': 1.58},
#    'dt': 1641596400},
#   {'main': {'aqi': 1},
#    'components': {'co': 390.53,
#     'no': 0.43,
#     'no2': 31.87,
#     'o3': 27.18,
#     'so2': 7.27,
#     'pm2_5': 3.6,
#     'pm10': 5.58,
#     'nh3': 1.74},
#    'dt': 1641600000},
#   {'main': {'aqi': 1},
#    'components': {'co': 403.88,
#     'no': 0.46,
#     'no2': 34.62,
#     'o3': 27.89,
#     'so2': 6.38,
#     'pm2_5': 4.87,
#     'pm10': 7.46,
#     'nh3': 2.15},
#    'dt': 1641603600},
#   {'main': {'aqi': 1},
#    'components': {'co': 420.57,
#     'no': 0.66,
#     'no2': 38.73,
#     'o3': 24.32,
#     'so2': 6.08,
#     'pm2_5': 6.31,
#     'pm10': 9.63,
#     'nh3': 2.6},
#    'dt': 1641607200},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 1.03,
#     'no2': 42.16,
#     'o3': 20.56,
#     'so2': 6.02,
#     'pm2_5': 7.59,
#     'pm10': 11.38,
#     'nh3': 2.91},
#    'dt': 1641610800},
#   {'main': {'aqi': 2},
#    'components': {'co': 423.91,
#     'no': 0.89,
#     'no2': 40.78,
#     'o3': 20.92,
#     'so2': 6.26,
#     'pm2_5': 7.06,
#     'pm10': 10.69,
#     'nh3': 2.72},
#    'dt': 1641614400},
#   {'main': {'aqi': 1},
#    'components': {'co': 367.16,
#     'no': 0.16,
#     'no2': 27.42,
#     'o3': 35.76,
#     'so2': 5.78,
#     'pm2_5': 3.66,
#     'pm10': 5.96,
#     'nh3': 1.69},
#    'dt': 1641618000},
#   {'main': {'aqi': 1},
#    'components': {'co': 327.11,
#     'no': 0.02,
#     'no2': 15.94,
#     'o3': 52.93,
#     'so2': 4.47,
#     'pm2_5': 1.72,
#     'pm10': 2.88,
#     'nh3': 1.01},
#    'dt': 1641621600},
#   {'main': {'aqi': 1},
#    'components': {'co': 317.1,
#     'no': 0.01,
#     'no2': 12,
#     'o3': 61.51,
#     'so2': 3.93,
#     'pm2_5': 1.28,
#     'pm10': 2.04,
#     'nh3': 0.83},
#    'dt': 1641625200},
#   {'main': {'aqi': 1},
#    'components': {'co': 320.43,
#     'no': 0.01,
#     'no2': 13.37,
#     'o3': 60.08,
#     'so2': 4.47,
#     'pm2_5': 1.54,
#     'pm10': 2.37,
#     'nh3': 0.89},
#    'dt': 1641628800},
#   {'main': {'aqi': 1},
#    'components': {'co': 323.77,
#     'no': 0.02,
#     'no2': 14.57,
#     'o3': 57.94,
#     'so2': 4.71,
#     'pm2_5': 1.8,
#     'pm10': 2.75,
#     'nh3': 0.94},
#    'dt': 1641632400},
#   {'main': {'aqi': 1},
#    'components': {'co': 327.11,
#     'no': 0.02,
#     'no2': 15.77,
#     'o3': 56.51,
#     'so2': 4.65,
#     'pm2_5': 2.09,
#     'pm10': 3.2,
#     'nh3': 1.03},
#    'dt': 1641636000},
#   {'main': {'aqi': 1},
#    'components': {'co': 340.46,
#     'no': 0.04,
#     'no2': 20.22,
#     'o3': 52.21,
#     'so2': 4.71,
#     'pm2_5': 3.04,
#     'pm10': 4.54,
#     'nh3': 1.35},
#    'dt': 1641639600},
#   {'main': {'aqi': 1},
#    'components': {'co': 403.88,
#     'no': 0.33,
#     'no2': 37.01,
#     'o3': 36.48,
#     'so2': 4.89,
#     'pm2_5': 6.78,
#     'pm10': 9.61,
#     'nh3': 2.5},
#    'dt': 1641643200},
#   {'main': {'aqi': 2},
#    'components': {'co': 487.33,
#     'no': 2.63,
#     'no2': 56.21,
#     'o3': 17.88,
#     'so2': 5.25,
#     'pm2_5': 11.21,
#     'pm10': 15.58,
#     'nh3': 3.83},
#    'dt': 1641646800},
#   {'main': {'aqi': 2},
#    'components': {'co': 534.06,
#     'no': 14.31,
#     'no2': 50.72,
#     'o3': 24.68,
#     'so2': 5.66,
#     'pm2_5': 13.58,
#     'pm10': 18.99,
#     'nh3': 4.56},
#    'dt': 1641650400},
#   {'main': {'aqi': 2},
#    'components': {'co': 534.06,
#     'no': 21.23,
#     'no2': 38.39,
#     'o3': 39.34,
#     'so2': 5.96,
#     'pm2_5': 14.26,
#     'pm10': 19.96,
#     'nh3': 4.62},
#    'dt': 1641654000},
#   {'main': {'aqi': 3},
#    'components': {'co': 600.81,
#     'no': 31.74,
#     'no2': 39.41,
#     'o3': 43.63,
#     'so2': 6.32,
#     'pm2_5': 20.1,
#     'pm10': 27.14,
#     'nh3': 5.64},
#    'dt': 1641657600},
#   {'main': {'aqi': 4},
#    'components': {'co': 761.03,
#     'no': 51.41,
#     'no2': 51.41,
#     'o3': 40.41,
#     'so2': 7.57,
#     'pm2_5': 33.1,
#     'pm10': 43.11,
#     'nh3': 7.85},
#    'dt': 1641661200},
#   {'main': {'aqi': 4},
#    'components': {'co': 934.6,
#     'no': 70.63,
#     'no2': 66.49,
#     'o3': 37.55,
#     'so2': 9.66,
#     'pm2_5': 48.31,
#     'pm10': 61.24,
#     'nh3': 10.01},
#    'dt': 1641664800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1094.82,
#     'no': 88.51,
#     'no2': 86.37,
#     'o3': 33.62,
#     'so2': 12.64,
#     'pm2_5': 63.67,
#     'pm10': 78.81,
#     'nh3': 12.29},
#    'dt': 1641668400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1281.74,
#     'no': 108.18,
#     'no2': 112.41,
#     'o3': 25.03,
#     'so2': 17.17,
#     'pm2_5': 82.41,
#     'pm10': 99.64,
#     'nh3': 15.07},
#    'dt': 1641672000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1441.96,
#     'no': 125.17,
#     'no2': 139.83,
#     'o3': 11.18,
#     'so2': 23.6,
#     'pm2_5': 96.32,
#     'pm10': 114.48,
#     'nh3': 17.73},
#    'dt': 1641675600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1575.47,
#     'no': 143.05,
#     'no2': 149.43,
#     'o3': 0.93,
#     'so2': 30.28,
#     'pm2_5': 98.71,
#     'pm10': 117.11,
#     'nh3': 20.52},
#    'dt': 1641679200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1708.98,
#     'no': 166.3,
#     'no2': 145.32,
#     'o3': 0,
#     'so2': 31.95,
#     'pm2_5': 97.17,
#     'pm10': 116.73,
#     'nh3': 22.8},
#    'dt': 1641682800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1815.8,
#     'no': 175.24,
#     'no2': 141.2,
#     'o3': 0,
#     'so2': 26.94,
#     'pm2_5': 98.32,
#     'pm10': 121.14,
#     'nh3': 24.07},
#    'dt': 1641686400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1815.8,
#     'no': 169.87,
#     'no2': 134.35,
#     'o3': 0,
#     'so2': 19.31,
#     'pm2_5': 99.6,
#     'pm10': 124.28,
#     'nh3': 23.56},
#    'dt': 1641690000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1522.06,
#     'no': 125.17,
#     'no2': 116.53,
#     'o3': 0,
#     'so2': 13.47,
#     'pm2_5': 80.25,
#     'pm10': 100.51,
#     'nh3': 18.24},
#    'dt': 1641693600},
#   {'main': {'aqi': 4},
#    'components': {'co': 1014.71,
#     'no': 59.01,
#     'no2': 100.08,
#     'o3': 0.02,
#     'so2': 11.09,
#     'pm2_5': 47.57,
#     'pm10': 60.03,
#     'nh3': 10.89},
#    'dt': 1641697200},
#   {'main': {'aqi': 2},
#    'components': {'co': 567.44,
#     'no': 5.53,
#     'no2': 78.14,
#     'o3': 8.76,
#     'so2': 9.78,
#     'pm2_5': 19.11,
#     'pm10': 24.59,
#     'nh3': 4.56},
#    'dt': 1641700800},
#   {'main': {'aqi': 2},
#    'components': {'co': 427.25,
#     'no': 0.12,
#     'no2': 45.93,
#     'o3': 39.34,
#     'so2': 8.23,
#     'pm2_5': 11.37,
#     'pm10': 14.54,
#     'nh3': 2.53},
#    'dt': 1641704400},
#   {'main': {'aqi': 1},
#    'components': {'co': 383.85,
#     'no': 0.02,
#     'no2': 33.59,
#     'o3': 55.07,
#     'so2': 8.23,
#     'pm2_5': 9.23,
#     'pm10': 11.57,
#     'nh3': 1.8},
#    'dt': 1641708000},
#   {'main': {'aqi': 1},
#    'components': {'co': 363.83,
#     'no': 0.01,
#     'no2': 29.47,
#     'o3': 57.94,
#     'so2': 8.58,
#     'pm2_5': 8.52,
#     'pm10': 10.59,
#     'nh3': 1.41},
#    'dt': 1641711600},
#   {'main': {'aqi': 1},
#    'components': {'co': 350.48,
#     'no': 0.01,
#     'no2': 27.76,
#     'o3': 57.94,
#     'so2': 8.94,
#     'pm2_5': 8.03,
#     'pm10': 9.96,
#     'nh3': 1.23},
#    'dt': 1641715200},
#   {'main': {'aqi': 1},
#    'components': {'co': 340.46,
#     'no': 0.01,
#     'no2': 25.7,
#     'o3': 59.37,
#     'so2': 8.82,
#     'pm2_5': 7.12,
#     'pm10': 8.85,
#     'nh3': 1.14},
#    'dt': 1641718800},
#   {'main': {'aqi': 1},
#    'components': {'co': 327.11,
#     'no': 0.01,
#     'no2': 23.31,
#     'o3': 62.23,
#     'so2': 8.23,
#     'pm2_5': 5.7,
#     'pm10': 7.22,
#     'nh3': 1.08},
#    'dt': 1641722400},
#   {'main': {'aqi': 1},
#    'components': {'co': 327.11,
#     'no': 0.01,
#     'no2': 23.99,
#     'o3': 62.94,
#     'so2': 7.87,
#     'pm2_5': 4.89,
#     'pm10': 6.43,
#     'nh3': 1.22},
#    'dt': 1641726000},
#   {'main': {'aqi': 1},
#    'components': {'co': 357.15,
#     'no': 0.03,
#     'no2': 32.22,
#     'o3': 55.79,
#     'so2': 7.57,
#     'pm2_5': 6.14,
#     'pm10': 8.21,
#     'nh3': 1.8},
#    'dt': 1641729600},
#   {'main': {'aqi': 2},
#    'components': {'co': 393.87,
#     'no': 0.1,
#     'no2': 41.47,
#     'o3': 45.06,
#     'so2': 7.63,
#     'pm2_5': 8.02,
#     'pm10': 10.7,
#     'nh3': 2.31},
#    'dt': 1641733200},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 0.54,
#     'no2': 44.55,
#     'o3': 41.84,
#     'so2': 7.33,
#     'pm2_5': 8.87,
#     'pm10': 11.71,
#     'nh3': 2.01},
#    'dt': 1641736800},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 1.41,
#     'no2': 42.16,
#     'o3': 44.7,
#     'so2': 7.03,
#     'pm2_5': 8.83,
#     'pm10': 11.69,
#     'nh3': 1.88},
#    'dt': 1641740400},
#   {'main': {'aqi': 1},
#    'components': {'co': 387.19,
#     'no': 2.24,
#     'no2': 38.04,
#     'o3': 47.92,
#     'so2': 6.97,
#     'pm2_5': 8.4,
#     'pm10': 10.76,
#     'nh3': 1.65},
#    'dt': 1641744000},
#   {'main': {'aqi': 1},
#    'components': {'co': 380.52,
#     'no': 3.19,
#     'no2': 35.99,
#     'o3': 48.64,
#     'so2': 7.33,
#     'pm2_5': 8.22,
#     'pm10': 10.12,
#     'nh3': 1.47},
#    'dt': 1641747600},
#   {'main': {'aqi': 1},
#    'components': {'co': 377.18,
#     'no': 4.3,
#     'no2': 34.27,
#     'o3': 49.35,
#     'so2': 7.51,
#     'pm2_5': 8.06,
#     'pm10': 9.73,
#     'nh3': 1.38},
#    'dt': 1641751200},
#   {'main': {'aqi': 1},
#    'components': {'co': 377.18,
#     'no': 4.58,
#     'no2': 33.59,
#     'o3': 47.92,
#     'so2': 7.57,
#     'pm2_5': 7.79,
#     'pm10': 9.3,
#     'nh3': 1.25},
#    'dt': 1641754800},
#   {'main': {'aqi': 1},
#    'components': {'co': 383.85,
#     'no': 3.02,
#     'no2': 38.39,
#     'o3': 40.77,
#     'so2': 7.99,
#     'pm2_5': 7.91,
#     'pm10': 9.44,
#     'nh3': 1.19},
#    'dt': 1641758400},
#   {'main': {'aqi': 2},
#    'components': {'co': 397.21,
#     'no': 1.4,
#     'no2': 44.55,
#     'o3': 31.83,
#     'so2': 8.11,
#     'pm2_5': 8.03,
#     'pm10': 9.6,
#     'nh3': 1.14},
#    'dt': 1641762000},
#   {'main': {'aqi': 2},
#    'components': {'co': 413.89,
#     'no': 0.66,
#     'no2': 52.09,
#     'o3': 22.17,
#     'so2': 7.75,
#     'pm2_5': 8.14,
#     'pm10': 9.78,
#     'nh3': 1.17},
#    'dt': 1641765600},
#   {'main': {'aqi': 2},
#    'components': {'co': 433.92,
#     'no': 1.12,
#     'no2': 56.89,
#     'o3': 15.38,
#     'so2': 7.03,
#     'pm2_5': 8.54,
#     'pm10': 10.34,
#     'nh3': 1.2},
#    'dt': 1641769200},
#   {'main': {'aqi': 2},
#    'components': {'co': 453.95,
#     'no': 1.7,
#     'no2': 57.58,
#     'o3': 11.8,
#     'so2': 5.9,
#     'pm2_5': 9.41,
#     'pm10': 11.52,
#     'nh3': 1.3},
#    'dt': 1641772800},
#   {'main': {'aqi': 2},
#    'components': {'co': 453.95,
#     'no': 1.79,
#     'no2': 54.84,
#     'o3': 11.27,
#     'so2': 5.01,
#     'pm2_5': 10.11,
#     'pm10': 12.42,
#     'nh3': 1.31},
#    'dt': 1641776400},
#   {'main': {'aqi': 2},
#    'components': {'co': 427.25,
#     'no': 0.71,
#     'no2': 45.93,
#     'o3': 18.78,
#     'so2': 4.17,
#     'pm2_5': 8.94,
#     'pm10': 11.04,
#     'nh3': 1.09},
#    'dt': 1641780000},
#   {'main': {'aqi': 1},
#    'components': {'co': 403.88,
#     'no': 0.21,
#     'no2': 37.01,
#     'o3': 28.97,
#     'so2': 3.81,
#     'pm2_5': 7.51,
#     'pm10': 9.27,
#     'nh3': 0.89},
#    'dt': 1641783600},
#   {'main': {'aqi': 1},
#    'components': {'co': 383.85,
#     'no': 0.07,
#     'no2': 29.13,
#     'o3': 37.19,
#     'so2': 3.87,
#     'pm2_5': 6.06,
#     'pm10': 7.66,
#     'nh3': 0.72},
#    'dt': 1641787200},
#   {'main': {'aqi': 1},
#    'components': {'co': 350.48,
#     'no': 0.02,
#     'no2': 21.08,
#     'o3': 43.99,
#     'so2': 3.99,
#     'pm2_5': 4.04,
#     'pm10': 5.28,
#     'nh3': 0.49},
#    'dt': 1641790800},
#   {'main': {'aqi': 1},
#    'components': {'co': 333.79,
#     'no': 0.01,
#     'no2': 17.99,
#     'o3': 47.92,
#     'so2': 4.05,
#     'pm2_5': 3,
#     'pm10': 4.04,
#     'nh3': 0.49},
#    'dt': 1641794400},
#   {'main': {'aqi': 1},
#    'components': {'co': 323.77,
#     'no': 0.01,
#     'no2': 14.22,
#     'o3': 50.78,
#     'so2': 3.49,
#     'pm2_5': 1.77,
#     'pm10': 2.57,
#     'nh3': 0.47},
#    'dt': 1641798000},
#   {'main': {'aqi': 1},
#    'components': {'co': 330.45,
#     'no': 0.01,
#     'no2': 13.19,
#     'o3': 50.07,
#     'so2': 4.17,
#     'pm2_5': 1.15,
#     'pm10': 1.86,
#     'nh3': 0.51},
#    'dt': 1641801600},
#   {'main': {'aqi': 1},
#    'components': {'co': 327.11,
#     'no': 0.01,
#     'no2': 12.51,
#     'o3': 52.93,
#     'so2': 4.53,
#     'pm2_5': 1.03,
#     'pm10': 1.73,
#     'nh3': 0.66},
#    'dt': 1641805200},
#   {'main': {'aqi': 1},
#    'components': {'co': 323.77,
#     'no': 0.01,
#     'no2': 11.82,
#     'o3': 57.94,
#     'so2': 4.23,
#     'pm2_5': 1.04,
#     'pm10': 1.75,
#     'nh3': 0.79},
#    'dt': 1641808800},
#   {'main': {'aqi': 1},
#    'components': {'co': 330.45,
#     'no': 0.02,
#     'no2': 14.05,
#     'o3': 57.22,
#     'so2': 4.35,
#     'pm2_5': 1.42,
#     'pm10': 2.32,
#     'nh3': 0.98},
#    'dt': 1641812400},
#   {'main': {'aqi': 1},
#    'components': {'co': 360.49,
#     'no': 0.07,
#     'no2': 22.96,
#     'o3': 48.64,
#     'so2': 4.65,
#     'pm2_5': 3.19,
#     'pm10': 4.85,
#     'nh3': 1.63},
#    'dt': 1641816000},
#   {'main': {'aqi': 1},
#    'components': {'co': 387.19,
#     'no': 0.29,
#     'no2': 30.85,
#     'o3': 41.13,
#     'so2': 4.95,
#     'pm2_5': 4.45,
#     'pm10': 6.73,
#     'nh3': 2.12},
#    'dt': 1641819600},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
#     'no': 2.65,
#     'no2': 25.36,
#     'o3': 49.35,
#     'so2': 4.77,
#     'pm2_5': 3.95,
#     'pm10': 6.1,
#     'nh3': 1.96},
#    'dt': 1641823200},
#   {'main': {'aqi': 1},
#    'components': {'co': 343.8,
#     'no': 3.97,
#     'no2': 16.62,
#     'o3': 62.23,
#     'so2': 4.17,
#     'pm2_5': 2.94,
#     'pm10': 4.66,
#     'nh3': 1.54},
#    'dt': 1641826800},
#   {'main': {'aqi': 1},
#    'components': {'co': 317.1,
#     'no': 3.69,
#     'no2': 11.31,
#     'o3': 72.96,
#     'so2': 3.61,
#     'pm2_5': 2.07,
#     'pm10': 3.32,
#     'nh3': 1.14},
#    'dt': 1641830400},
#   {'main': {'aqi': 1},
#    'components': {'co': 310.42,
#     'no': 3.69,
#     'no2': 10.54,
#     'o3': 77.96,
#     'so2': 3.73,
#     'pm2_5': 1.95,
#     'pm10': 3.1,
#     'nh3': 1.03},
#    'dt': 1641834000},
#   {'main': {'aqi': 2},
#    'components': {'co': 307.08,
#     'no': 3.55,
#     'no2': 10.37,
#     'o3': 80.11,
#     'so2': 3.73,
#     'pm2_5': 1.97,
#     'pm10': 3.05,
#     'nh3': 0.97},
#    'dt': 1641837600},
#   {'main': {'aqi': 1},
#    'components': {'co': 310.42,
#     'no': 3.38,
#     'no2': 11.31,
#     'o3': 78.68,
#     'so2': 3.87,
#     'pm2_5': 2.15,
#     'pm10': 3.27,
#     'nh3': 0.99},
#    'dt': 1641841200},
#   {'main': {'aqi': 1},
#    'components': {'co': 317.1,
#     'no': 3.21,
#     'no2': 14.74,
#     'o3': 75.82,
#     'so2': 4.59,
#     'pm2_5': 2.59,
#     'pm10': 3.9,
#     'nh3': 1.16},
#    'dt': 1641844800},
#   {'main': {'aqi': 1},
#    'components': {'co': 323.77,
#     'no': 1.9,
#     'no2': 20.05,
#     'o3': 70.81,
#     'so2': 5.19,
#     'pm2_5': 2.92,
#     'pm10': 4.41,
#     'nh3': 1.35},
#    'dt': 1641848400},
#   {'main': {'aqi': 1},
#    'components': {'co': 343.8,
#     'no': 0.25,
#     'no2': 28.79,
#     'o3': 61.51,
#     'so2': 6.2,
#     'pm2_5': 3.48,
#     'pm10': 5.28,
#     'nh3': 1.66},
#    'dt': 1641852000},
# ...
#     'pm2_5': 11.98,
#     'pm10': 15.47,
#     'nh3': 2.5},
#    'dt': 1644393600},
#   {'main': {'aqi': 2},
#    'components': {'co': 500.68,
#     'no': 6.71,
#     'no2': 42.84,
#     'o3': 1.31,
#     'so2': 13.83,
#     'pm2_5': 13.23,
#     'pm10': 17.01,
#     'nh3': 2.72},
#    'dt': 1644397200},
#   {'main': {'aqi': 2},
#    'components': {'co': 560.76,
#     'no': 16.32,
#     'no2': 43.87,
#     'o3': 0.21,
#     'so2': 13.59,
#     'pm2_5': 17.64,
#     'pm10': 22.59,
#     'nh3': 3.8},
#    'dt': 1644400800},
#   {'main': {'aqi': 4},
#    'components': {'co': 714.3,
#     'no': 40.23,
#     'no2': 47.98,
#     'o3': 0,
#     'so2': 14.54,
#     'pm2_5': 28.16,
#     'pm10': 35.85,
#     'nh3': 6.59},
#    'dt': 1644404400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1188.28,
#     'no': 110.86,
#     'no2': 59.63,
#     'o3': 0,
#     'so2': 18.36,
#     'pm2_5': 60.08,
#     'pm10': 75.22,
#     'nh3': 15.07},
#    'dt': 1644408000},
#   {'main': {'aqi': 5},
#    'components': {'co': 2002.72,
#     'no': 232.46,
#     'no2': 76.09,
#     'o3': 0.29,
#     'so2': 25.75,
#     'pm2_5': 110.71,
#     'pm10': 136.79,
#     'nh3': 29.13},
#    'dt': 1644411600},
#   {'main': {'aqi': 5},
#    'components': {'co': 2563.48,
#     'no': 318.29,
#     'no2': 87.05,
#     'o3': 2.3,
#     'so2': 29.09,
#     'pm2_5': 144.7,
#     'pm10': 177.76,
#     'nh3': 36.48},
#    'dt': 1644415200},
#   {'main': {'aqi': 5},
#    'components': {'co': 2670.29,
#     'no': 318.29,
#     'no2': 97.33,
#     'o3': 5.63,
#     'so2': 26.46,
#     'pm2_5': 152.72,
#     'pm10': 187.18,
#     'nh3': 32.42},
#    'dt': 1644418800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1028.06,
#     'no': 94.77,
#     'no2': 69.23,
#     'o3': 18.95,
#     'so2': 42.92,
#     'pm2_5': 52.45,
#     'pm10': 64.32,
#     'nh3': 10.39},
#    'dt': 1644422400},
#   {'main': {'aqi': 4},
#    'components': {'co': 814.44,
#     'no': 64.37,
#     'no2': 65.12,
#     'o3': 27.89,
#     'so2': 39.1,
#     'pm2_5': 45.28,
#     'pm10': 54.95,
#     'nh3': 7.28},
#    'dt': 1644426000},
#   {'main': {'aqi': 4},
#    'components': {'co': 720.98,
#     'no': 49.17,
#     'no2': 60.32,
#     'o3': 33.62,
#     'so2': 35.76,
#     'pm2_5': 41,
#     'pm10': 49.32,
#     'nh3': 5.57},
#    'dt': 1644429600},
#   {'main': {'aqi': 4},
#    'components': {'co': 674.25,
#     'no': 37.55,
#     'no2': 56.89,
#     'o3': 37.55,
#     'so2': 31.95,
#     'pm2_5': 38.6,
#     'pm10': 45.93,
#     'nh3': 4.69},
#    'dt': 1644433200},
#   {'main': {'aqi': 4},
#    'components': {'co': 634.19,
#     'no': 30.4,
#     'no2': 56.21,
#     'o3': 37.91,
#     'so2': 29.09,
#     'pm2_5': 34.55,
#     'pm10': 41.03,
#     'nh3': 4.37},
#    'dt': 1644436800},
#   {'main': {'aqi': 3},
#    'components': {'co': 560.76,
#     'no': 21.01,
#     'no2': 52.78,
#     'o3': 32.19,
#     'so2': 23.6,
#     'pm2_5': 24.41,
#     'pm10': 29.84,
#     'nh3': 3.93},
#    'dt': 1644440400},
#   {'main': {'aqi': 3},
#    'components': {'co': 547.41,
#     'no': 12.29,
#     'no2': 60.32,
#     'o3': 16.09,
#     'so2': 19.55,
#     'pm2_5': 20.01,
#     'pm10': 25.16,
#     'nh3': 3.83},
#    'dt': 1644444000},
#   {'main': {'aqi': 3},
#    'components': {'co': 580.79,
#     'no': 9.83,
#     'no2': 67.86,
#     'o3': 2.28,
#     'so2': 16.93,
#     'pm2_5': 20.95,
#     'pm10': 26.2,
#     'nh3': 3.96},
#    'dt': 1644447600},
#   {'main': {'aqi': 3},
#    'components': {'co': 614.17,
#     'no': 13.97,
#     'no2': 67.17,
#     'o3': 0.86,
#     'so2': 14.07,
#     'pm2_5': 23.17,
#     'pm10': 28.74,
#     'nh3': 3.96},
#    'dt': 1644451200},
#   {'main': {'aqi': 4},
#    'components': {'co': 847.82,
#     'no': 42.92,
#     'no2': 73.34,
#     'o3': 0.08,
#     'so2': 9.89,
#     'pm2_5': 37.01,
#     'pm10': 45.73,
#     'nh3': 4.5},
#    'dt': 1644454800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1228.33,
#     'no': 90.3,
#     'no2': 85.68,
#     'o3': 0,
#     'so2': 7.33,
#     'pm2_5': 61.21,
#     'pm10': 75.49,
#     'nh3': 4.94},
#    'dt': 1644458400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1468.66,
#     'no': 121.59,
#     'no2': 95.96,
#     'o3': 0,
#     'so2': 6.32,
#     'pm2_5': 77.04,
#     'pm10': 96.06,
#     'nh3': 5.83},
#    'dt': 1644462000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1482.01,
#     'no': 119.81,
#     'no2': 102.82,
#     'o3': 0,
#     'so2': 6.26,
#     'pm2_5': 75.89,
#     'pm10': 95.93,
#     'nh3': 5.83},
#    'dt': 1644465600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1148.22,
#     'no': 78.68,
#     'no2': 95.96,
#     'o3': 0,
#     'so2': 6.2,
#     'pm2_5': 52.83,
#     'pm10': 68.06,
#     'nh3': 3.32},
#    'dt': 1644469200},
#   {'main': {'aqi': 4},
#    'components': {'co': 841.14,
#     'no': 42.92,
#     'no2': 82.94,
#     'o3': 0.01,
#     'so2': 6.26,
#     'pm2_5': 34.1,
#     'pm10': 44.73,
#     'nh3': 2.25},
#    'dt': 1644472800},
#   {'main': {'aqi': 3},
#    'components': {'co': 667.57,
#     'no': 21.46,
#     'no2': 75.4,
#     'o3': 0.18,
#     'so2': 6.26,
#     'pm2_5': 24.12,
#     'pm10': 32.04,
#     'nh3': 1.85},
#    'dt': 1644476400},
#   {'main': {'aqi': 2},
#    'components': {'co': 580.79,
#     'no': 10.17,
#     'no2': 70.6,
#     'o3': 1.23,
#     'so2': 6.32,
#     'pm2_5': 19.24,
#     'pm10': 25.81,
#     'nh3': 1.47},
#    'dt': 1644480000},
#   {'main': {'aqi': 2},
#    'components': {'co': 514.03,
#     'no': 3.8,
#     'no2': 65.12,
#     'o3': 5.19,
#     'so2': 6.85,
#     'pm2_5': 16,
#     'pm10': 21.83,
#     'nh3': 1.22},
#    'dt': 1644483600},
#   {'main': {'aqi': 2},
#    'components': {'co': 480.65,
#     'no': 1.82,
#     'no2': 60.32,
#     'o3': 9.3,
#     'so2': 7.27,
#     'pm2_5': 14.35,
#     'pm10': 19.68,
#     'nh3': 1.16},
#    'dt': 1644487200},
#   {'main': {'aqi': 2},
#    'components': {'co': 500.68,
#     'no': 3.86,
#     'no2': 63.75,
#     'o3': 5.63,
#     'so2': 7.27,
#     'pm2_5': 16.07,
#     'pm10': 21.51,
#     'nh3': 1.39},
#    'dt': 1644490800},
#   {'main': {'aqi': 4},
#    'components': {'co': 667.57,
#     'no': 24.59,
#     'no2': 74.03,
#     'o3': 0.3,
#     'so2': 7.63,
#     'pm2_5': 25.64,
#     'pm10': 33.23,
#     'nh3': 2.82},
#    'dt': 1644494400},
#   {'main': {'aqi': 4},
#    'components': {'co': 894.55,
#     'no': 56.77,
#     'no2': 85.68,
#     'o3': 1.25,
#     'so2': 8.7,
#     'pm2_5': 37.37,
#     'pm10': 47.99,
#     'nh3': 4.24},
#    'dt': 1644498000},
#   {'main': {'aqi': 4},
#    'components': {'co': 961.3,
#     'no': 72.42,
#     'no2': 82.94,
#     'o3': 8.94,
#     'so2': 10.25,
#     'pm2_5': 41.38,
#     'pm10': 53.4,
#     'nh3': 4.37},
#    'dt': 1644501600},
#   {'main': {'aqi': 4},
#    'components': {'co': 854.49,
#     'no': 63.48,
#     'no2': 69.23,
#     'o3': 18.6,
#     'so2': 13.11,
#     'pm2_5': 38.72,
#     'pm10': 49.84,
#     'nh3': 4.37},
#    'dt': 1644505200},
#   {'main': {'aqi': 3},
#    'components': {'co': 527.38,
#     'no': 24.36,
#     'no2': 42.5,
#     'o3': 40.77,
#     'so2': 13.71,
#     'pm2_5': 22.16,
#     'pm10': 28.05,
#     'nh3': 2.56},
#    'dt': 1644508800},
#   {'main': {'aqi': 2},
#    'components': {'co': 403.88,
#     'no': 12.07,
#     'no2': 26.05,
#     'o3': 55.07,
#     'so2': 10.61,
#     'pm2_5': 12.27,
#     'pm10': 15.82,
#     'nh3': 1.82},
#    'dt': 1644512400},
#   {'main': {'aqi': 1},
#    'components': {'co': 347.14,
#     'no': 6.93,
#     'no2': 17.48,
#     'o3': 65.09,
#     'so2': 8.11,
#     'pm2_5': 6.43,
#     'pm10': 8.64,
#     'nh3': 1.49},
#    'dt': 1644516000},
#   {'main': {'aqi': 1},
#    'components': {'co': 307.08,
#     'no': 3.74,
#     'no2': 11.82,
#     'o3': 75.82,
#     'so2': 5.54,
#     'pm2_5': 3.02,
#     'pm10': 4.32,
#     'nh3': 1.41},
#    'dt': 1644519600},
#   {'main': {'aqi': 1},
#    'components': {'co': 303.75,
#     'no': 3.44,
#     'no2': 13.88,
#     'o3': 77.96,
#     'so2': 5.48,
#     'pm2_5': 2.37,
#     'pm10': 3.57,
#     'nh3': 1.55},
#    'dt': 1644523200},
#   {'main': {'aqi': 1},
#    'components': {'co': 313.76,
#     'no': 2.82,
#     'no2': 17.82,
#     'o3': 74.39,
#     'so2': 5.78,
#     'pm2_5': 2.42,
#     'pm10': 3.72,
#     'nh3': 1.68},
#    'dt': 1644526800},
#   {'main': {'aqi': 1},
#    'components': {'co': 367.16,
#     'no': 2.04,
#     'no2': 34.96,
#     'o3': 53.64,
#     'so2': 6.91,
#     'pm2_5': 3.87,
#     'pm10': 5.94,
#     'nh3': 2.37},
#    'dt': 1644530400},
#   {'main': {'aqi': 2},
#    'components': {'co': 440.6,
#     'no': 0.6,
#     'no2': 56.89,
#     'o3': 25.03,
#     'so2': 7.57,
#     'pm2_5': 6.08,
#     'pm10': 9.34,
#     'nh3': 3.26},
#    'dt': 1644534000},
#   {'main': {'aqi': 2},
#    'components': {'co': 494,
#     'no': 2.71,
#     'no2': 67.86,
#     'o3': 10.01,
#     'so2': 7.45,
#     'pm2_5': 8.76,
#     'pm10': 13.25,
#     'nh3': 4.02},
#    'dt': 1644537600},
#   {'main': {'aqi': 2},
#    'components': {'co': 680.92,
#     'no': 27.72,
#     'no2': 74.71,
#     'o3': 0.75,
#     'so2': 6.56,
#     'pm2_5': 19.06,
#     'pm10': 26.75,
#     'nh3': 6.52},
#    'dt': 1644541200},
#   {'main': {'aqi': 4},
#    'components': {'co': 974.66,
#     'no': 68.84,
#     'no2': 80.2,
#     'o3': 0,
#     'so2': 5.78,
#     'pm2_5': 36.47,
#     'pm10': 49.05,
#     'nh3': 9.75},
#    'dt': 1644544800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1241.68,
#     'no': 102.82,
#     'no2': 86.37,
#     'o3': 0,
#     'so2': 5.84,
#     'pm2_5': 54.68,
#     'pm10': 72.38,
#     'nh3': 11.27},
#    'dt': 1644548400},
#   {'main': {'aqi': 5},
#    'components': {'co': 1455.31,
#     'no': 126.96,
#     'no2': 90.48,
#     'o3': 0,
#     'so2': 6.5,
#     'pm2_5': 68.22,
#     'pm10': 89.88,
#     'nh3': 10.26},
#    'dt': 1644552000},
#   {'main': {'aqi': 5},
#    'components': {'co': 1415.25,
#     'no': 119.81,
#     'no2': 89.11,
#     'o3': 0,
#     'so2': 6.32,
#     'pm2_5': 63.74,
#     'pm10': 84.93,
#     'nh3': 5.89},
#    'dt': 1644555600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1308.44,
#     'no': 105.5,
#     'no2': 86.37,
#     'o3': 0,
#     'so2': 7.63,
#     'pm2_5': 57.08,
#     'pm10': 76.65,
#     'nh3': 5.64},
#    'dt': 1644559200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1214.98,
#     'no': 91.2,
#     'no2': 82.25,
#     'o3': 0,
#     'so2': 8.94,
#     'pm2_5': 52.35,
#     'pm10': 70.28,
#     'nh3': 6.78},
#    'dt': 1644562800},
#   {'main': {'aqi': 5},
#    'components': {'co': 1161.58,
#     'no': 85.83,
#     'no2': 78.83,
#     'o3': 0,
#     'so2': 9.54,
#     'pm2_5': 50.8,
#     'pm10': 68.03,
#     'nh3': 7.35},
#    'dt': 1644566400},
#   {'main': {'aqi': 4},
#    'components': {'co': 1094.82,
#     'no': 78.68,
#     'no2': 72.66,
#     'o3': 0,
#     'so2': 9.78,
#     'pm2_5': 47.69,
#     'pm10': 64,
#     'nh3': 7.66},
#    'dt': 1644570000},
#   {'main': {'aqi': 4},
#    'components': {'co': 961.3,
#     'no': 64.37,
#     'no2': 61.69,
#     'o3': 0,
#     'so2': 9.42,
#     'pm2_5': 39.77,
#     'pm10': 54.21,
#     'nh3': 7.22},
#    'dt': 1644573600},
#   {'main': {'aqi': 4},
#    'components': {'co': 947.95,
#     'no': 70.63,
#     'no2': 56.89,
#     'o3': 0,
#     'so2': 10.85,
#     'pm2_5': 40.68,
#     'pm10': 55.24,
#     'nh3': 8.61},
#    'dt': 1644577200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1388.55,
#     'no': 139.47,
#     'no2': 63.06,
#     'o3': 0,
#     'so2': 14.78,
#     'pm2_5': 69.45,
#     'pm10': 90.88,
#     'nh3': 16.72},
#    'dt': 1644580800},
#   {'main': {'aqi': 5},
#    'components': {'co': 2243.04,
#     'no': 278.95,
#     'no2': 79.51,
#     'o3': 0.28,
#     'so2': 22.17,
#     'pm2_5': 122.97,
#     'pm10': 156.98,
#     'nh3': 30.65},
#    'dt': 1644584400},
#   {'main': {'aqi': 5},
#    'components': {'co': 3124.24,
#     'no': 422,
#     'no2': 100.08,
#     'o3': 2.08,
#     'so2': 24.32,
#     'pm2_5': 179.35,
#     'pm10': 223.14,
#     'nh3': 32.93},
#    'dt': 1644588000},
#   {'main': {'aqi': 5},
#    'components': {'co': 3845.21,
#     'no': 514.98,
#     'no2': 138.46,
#     'o3': 4.96,
#     'so2': 25.27,
#     'pm2_5': 239.26,
#     'pm10': 287.72,
#     'nh3': 32.17},
#    'dt': 1644591600},
#   {'main': {'aqi': 5},
#    'components': {'co': 1869.2,
#     'no': 194.91,
#     'no2': 124.75,
#     'o3': 16.27,
#     'so2': 42.44,
#     'pm2_5': 118.53,
#     'pm10': 140.21,
#     'nh3': 12.79},
#    'dt': 1644595200},
#   {'main': {'aqi': 5},
#    'components': {'co': 1228.33,
#     'no': 95.67,
#     'no2': 105.56,
#     'o3': 28.97,
#     'so2': 35.76,
#     'pm2_5': 86.22,
#     'pm10': 102.12,
#     'nh3': 6.33},
#    'dt': 1644598800},
#   {'main': {'aqi': 5},
#    'components': {'co': 841.14,
#     'no': 50.51,
#     'no2': 69.92,
#     'o3': 35.05,
#     'so2': 28.61,
#     'pm2_5': 52.91,
#     'pm10': 63.7,
#     'nh3': 4.05},
#    'dt': 1644602400},
#   {'main': {'aqi': 4},
#    'components': {'co': 580.79,
#     'no': 25.48,
#     'no2': 45.93,
#     'o3': 42.2,
#     'so2': 20.98,
#     'pm2_5': 28.26,
#     'pm10': 35.14,
#     'nh3': 3.23},
#    'dt': 1644606000},
#   {'main': {'aqi': 3},
#    'components': {'co': 507.35,
#     'no': 17.88,
#     'no2': 41.81,
#     'o3': 45.06,
#     'so2': 18.36,
#     'pm2_5': 22.92,
#     'pm10': 29.53,
#     'nh3': 3.36},
#    'dt': 1644609600},
#   {'main': {'aqi': 3},
#    'components': {'co': 487.33,
#     'no': 11.18,
#     'no2': 42.5,
#     'o3': 47.21,
#     'so2': 15.02,
#     'pm2_5': 23.09,
#     'pm10': 29.52,
#     'nh3': 3.23},
#    'dt': 1644613200},
#   {'main': {'aqi': 4},
#    'components': {'co': 487.33,
#     'no': 3.58,
#     'no2': 50.72,
#     'o3': 38.27,
#     'so2': 13.23,
#     'pm2_5': 25.92,
#     'pm10': 32.13,
#     'nh3': 3.32},
#    'dt': 1644616800},
#   {'main': {'aqi': 4},
#    'components': {'co': 500.68,
#     'no': 0.47,
#     'no2': 57.58,
#     'o3': 25.75,
#     'so2': 12.64,
#     'pm2_5': 26.87,
#     'pm10': 32.12,
#     'nh3': 3.86},
#    'dt': 1644620400},
#   {'main': {'aqi': 3},
#    'components': {'co': 494,
#     'no': 0.5,
#     'no2': 58.26,
#     'o3': 23.6,
#     'so2': 10.01,
#     'pm2_5': 20.51,
#     'pm10': 24.79,
#     'nh3': 4.05},
#    'dt': 1644624000},
#   {'main': {'aqi': 2},
#    'components': {'co': 447.27,
#     'no': 0.15,
#     'no2': 51.41,
#     'o3': 34.33,
#     'so2': 8.34,
#     'pm2_5': 13.45,
#     'pm10': 17.18,
#     'nh3': 4.05},
#    'dt': 1644627600},
#   {'main': {'aqi': 2},
#    'components': {'co': 400.54,
#     'no': 0.02,
#     'no2': 41.81,
#     'o3': 49.35,
#     'so2': 7.75,
#     'pm2_5': 10.53,
#     'pm10': 13.75,
#     'nh3': 3.51},
#    'dt': 1644631200},
#   {'main': {'aqi': 1},
#    'components': {'co': 370.5,
#     'no': 0,
#     'no2': 35.3,
#     'o3': 60.08,
#     'so2': 7.21,
#     'pm2_5': 9.1,
#     'pm10': 12.03,
#     'nh3': 3.13},
#    'dt': 1644634800},
#   {'main': {'aqi': 1},
#    'components': {'co': 340.46,
#     'no': 0,
#     'no2': 28.45,
#     'o3': 67.95,
#     'so2': 6.56,
#     'pm2_5': 7.95,
#     'pm10': 10.52,
#     'nh3': 2.79},
#    'dt': 1644638400},
#   {'main': {'aqi': 1},
#    'components': {'co': 307.08,
#     'no': 0,
#     'no2': 21.25,
#     'o3': 75.1,
#     'so2': 6.2,
#     'pm2_5': 6.63,
#     'pm10': 8.64,
#     'nh3': 2.37},
#    'dt': 1644642000},
#   {'main': {'aqi': 2},
#    'components': {'co': 287.06,
#     'no': 0,
#     'no2': 15.94,
#     'o3': 80.82,
#     'so2': 5.3,
#     'pm2_5': 6.19,
#     'pm10': 7.86,
#     'nh3': 2.25},
#    'dt': 1644645600},
#   {'main': {'aqi': 2},
#    'components': {'co': 280.38,
#     'no': 0,
#     'no2': 14.05,
#     'o3': 82.25,
#     'so2': 4.95,
#     'pm2_5': 6.5,
#     'pm10': 8.19,
#     'nh3': 2.5},
#    'dt': 1644649200},
#   {'main': {'aqi': 2},
#    'components': {'co': 280.38,
#     'no': 0,
#     'no2': 14.91,
#     'o3': 80.11,
#     'so2': 5.48,
#     'pm2_5': 7.59,
#     'pm10': 9.55,
#     'nh3': 2.91},
#    'dt': 1644652800},
#   {'main': {'aqi': 1},
#    'components': {'co': 287.06,
#     'no': 0,
#     'no2': 17.48,
#     'o3': 74.39,
#     'so2': 6.5,
#     'pm2_5': 9.74,
#     'pm10': 12.07,
#     'nh3': 3.26},
#    'dt': 1644656400},
#   {'main': {'aqi': 2},
#    'components': {'co': 303.75,
#     'no': 0,
#     'no2': 21.25,
#     'o3': 67.95,
#     'so2': 7.57,
#     'pm2_5': 11.96,
#     'pm10': 14.59,
#     'nh3': 3.51},
#    'dt': 1644660000},
#   {'main': {'aqi': 2},
#    'components': {'co': 320.43,
#     'no': 0,
#     'no2': 26.39,
#     'o3': 60.8,
#     'so2': 8.58,
#     'pm2_5': 13.06,
#     'pm10': 16,
#     'nh3': 3.61},
#    'dt': 1644663600},
#   {'main': {'aqi': 2},
#    'components': {'co': 367.16,
#     'no': 0.02,
#     'no2': 38.73,
#     'o3': 46.49,
#     'so2': 9.3,
#     'pm2_5': 15.12,
#     'pm10': 18.89,
#     'nh3': 3.96},
#    'dt': 1644667200},
#   {'main': {'aqi': 2},
#    'components': {'co': 423.91,
#     'no': 0.87,
#     'no2': 52.09,
#     'o3': 31.83,
#     'so2': 10.01,
#     'pm2_5': 17.84,
#     'pm10': 22.65,
#     'nh3': 4.43},
#    'dt': 1644670800},
#   {'main': {'aqi': 2},
#    'components': {'co': 440.6,
#     'no': 5.92,
#     'no2': 49.35,
#     'o3': 33.62,
#     'so2': 10.37,
#     'pm2_5': 19.32,
#     'pm10': 24.76,
#     'nh3': 4.62},
#    'dt': 1644674400},
#   {'main': {'aqi': 2},
#    'components': {'co': 427.25,
#     'no': 9.28,
#     'no2': 36.67,
#     'o3': 45.06,
#     'so2': 10.01,
#     'pm2_5': 19.09,
#     'pm10': 24.44,
#     'nh3': 4.5},
#    'dt': 1644678000},
#   ...]}

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
import time

# OpenWeatherMap API key

api_key = "25e2ab59c6e50eab30c8c23334c7370f"

# dataset with city coordinates
df = merged_final_df

# 'AQI' column to the DataFrame 

if 'AQI' not in df.columns:
    df['AQI'] = None

# Function to generate a list of sample days (one day per week for a year)

def generate_sample_days():
    start_date = datetime(2022, 1, 1)  # Start at the beginning of the year
    sample_days = [start_date + timedelta(weeks=i) for i in range(52)]  # Generate 52 dates (one per week)
    return sample_days

# Function to calculate AQI based on pollutant concentrations

def calculate_aqi(components):
    aqi_levels = {
        'SO2': [20, 80, 250, 350],
        'NO2': [40, 70, 150, 200],
        'PM10': [20, 50, 100, 200],
        'PM2_5': [10, 25, 50, 75],
        'O3': [60, 100, 140, 180],
        'CO': [4400, 9400, 12400, 15400]
    }

    def get_aqi(concentration, breakpoints):
        if concentration < breakpoints[0]:
            return 1  # Good
        elif concentration < breakpoints[1]:
            return 2  # Fair
        elif concentration < breakpoints[2]:
            return 3  # Moderate
        elif concentration < breakpoints[3]:
            return 4  # Poor
        else:
            return 5  # Very Poor

    aqi_values = []
    for pollutant, breakpoints in aqi_levels.items():
        concentration = components.get(pollutant.lower(), 0)
        aqi_value = get_aqi(concentration, breakpoints)
        aqi_values.append(aqi_value)

    overall_aqi = max(aqi_values)
    return overall_aqi

# Function to fetch air quality data for a city

def fetch_air_quality(lat, lon, api_key, sample_days):
    session = requests.Session()
    aqi_values = []
    for day in sample_days:
        start_time = int(day.timestamp())
        end_time = int((day + timedelta(days=1)).timestamp())
        url = f"https://api.openweathermap.org/data/2.5/air_pollution/history?lat={lat}&lon={lon}&start={start_time}&end={end_time}&appid={api_key}"
        try:
            response = session.get(url)
            response.raise_for_status()
            data = response.json()
            if 'list' in data and len(data['list']) > 0:
                for entry in data['list']:
                    components = entry['components']
                    aqi = calculate_aqi(components)
                    aqi_values.append(aqi)
        except requests.exceptions.RequestException as e:
            print(f"Request failed: {e}")
            time.sleep(60)  # Add a delay before retrying

    if aqi_values:
        return sum(aqi_values) / len(aqi_values)  # Return the average AQI for the sample days
    return None

# Generate sample days for the entire year (one per week)

sample_days = generate_sample_days()

# Start processing from the xth city in the DataFrame, because the process was done in batches with different API keys

start_position = 3330
for index, row in df.iloc[start_position:].iterrows():
    lat, lon = row['lat'], row['lng']
    avg_aqi = fetch_air_quality(lat, lon, api_key, sample_days)
    df.at[index, 'AQI'] = avg_aqi

    # Save the DataFrame to a CSV file after every 10 cities

    if (index + 1) % 10 == 0:
        df.to_csv('/Users/alexandreribeiro/Documents/GitHub/final_project/notebooks/aqi_df.csv', index=False)
        print(f"Progress saved after processing {index + 1} cities.")

# Save the final DataFrame

df.to_csv('/Users/alexandreribeiro/Documents/GitHub/final_project/notebooks/aqi_final_df.csv', index=False)
print("\nProcessing complete. Final data saved to '/Users/alexandreribeiro/Documents/GitHub/final_project/notebooks/aqi_final_df.csv'.")
# Out:
# Progress saved after processing 3340 cities.
# Progress saved after processing 3350 cities.
# Progress saved after processing 3360 cities.
#
# Processing complete. Final data saved to '/Users/alexandreribeiro/Documents/GitHub/final_project/notebooks/aqi_final_df.csv'.

# %%
data = "https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/clean/aqi_df.csv"

data_cleaned_merged = pd.read_csv(data, delimiter=',')

# %%
data_cleaned_merged
# Out:
#            city      lat       lng        country         state  \
# 0      New York  40.6943  -73.9249  United States      New York
# 1       Chicago  41.8375  -87.6866  United States      Illinois
# 2         Miami  25.7840  -80.2101  United States       Florida
# 3       Houston  29.7860  -95.3885  United States         Texas
# 4        Dallas  32.7935  -96.7667  United States         Texas
# ...         ...      ...       ...            ...           ...
# 3356    Delavan  42.6282  -88.6323  United States     Wisconsin
# 3357  Evergreen  48.2308 -114.2700  United States       Montana
# 3358  Sutherlin  43.3882 -123.3242  United States        Oregon
# 3359    Altoona  44.8029  -91.4385  United States     Wisconsin
# 3360  Old Forge  41.3704  -75.7409  United States  Pennsylvania
#
#       population_city  greenspacearea_km2  obesity_rate  smoking_rate  \
# 0          18908608.0                9.58          30.1          11.5
# 1           8497759.0                0.29          33.4          12.8
# 2           6080145.0               35.57          31.6          12.0
# 3           5970127.0               52.57          35.5          12.0
# 4           5830932.0               79.91          35.5          12.0
# ...               ...                 ...           ...           ...
# 3356           8519.0               17.37          37.7          15.0
# 3357           8514.0                0.96          30.5          16.0
# 3358           8513.0               54.94          30.9          12.8
# 3359           8506.0                0.27          37.7          15.0
# 3360           8506.0               36.90          33.4          15.6
#
#       exercising_rate  chronic_rate  life_expectancy  population_state  \
# 0                50.7          15.7             77.7          19571216
# 1                50.0          15.6             76.8          12549689
# 2                54.3          16.5             77.5          22610726
# 3                49.4          16.6             76.5          30503301
# 4                49.4          16.6             76.5          30503301
# ...               ...           ...              ...               ...
# 3356             55.0          17.0             77.7           5910955
# 3357             63.2          16.4             76.8           1132812
# 3358             56.8          17.4             78.8           4233358
# 3359             55.0          17.0             77.7           5910955
# 3360             50.8          18.5             76.8          12961683
#
#       adjusted_obesity_rate  adjusted_smoking_rate  adjusted_exercising_rate  \
# 0                 29.080927              11.110653                 48.983488
# 1                 22.616110               8.667252                 33.856453
# 2                  8.497409               3.226864                 14.601560
# 3                  6.948084               2.348648                  9.668602
# 4                  6.786088               2.293889                  9.443176
# ...                     ...                    ...                       ...
# 3356               0.054334               0.021618                  0.079267
# 3357               0.229232               0.120253                  0.474999
# 3358               0.062138               0.025740                  0.114221
# 3359               0.054251               0.021585                  0.079146
# 3360               0.021918               0.010237                  0.033337
#
#       adjusted_chronic_rate  adjusted_life_expectancy       AQI
# 0                 15.168457                 75.069369  2.013333
# 1                 10.563213                 52.003511  1.930196
# 2                  4.436938                 20.840164  1.639216
# 3                  3.248963                 14.972632  1.789020
# 4                  3.173213                 14.623542  1.880000
# ...                     ...                       ...       ...
# 3356               0.024501                  0.111983  1.854902
# 3357               0.123259                  0.577214  1.510588
# 3358               0.034990                  0.158462  1.381176
# 3359               0.024463                  0.111812  1.692549
# 3360               0.012140                  0.050399       NaN
#
# [3361 rows x 19 columns]

# %%
data_cleaned_merged.columns
# Out:
# Index(['city', 'lat', 'lng', 'country', 'state', 'population_city',
#        'greenspacearea_km2', 'obesity_rate', 'smoking_rate', 'exercising_rate',
#        'chronic_rate', 'life_expectancy', 'population_state',
#        'adjusted_obesity_rate', 'adjusted_smoking_rate',
#        'adjusted_exercising_rate', 'adjusted_chronic_rate',
#        'adjusted_life_expectancy', 'AQI'],
#       dtype='object')

# %%
data2 = "https://raw.githubusercontent.com/AlexRibeiro95/Environmental_factors_on_Public_health/main/data/raw/adjusted_city_level_metrics.csv"

data_cleaned = pd.read_csv(data2)

# %%
data_cleaned
# Out:
#            city      lat       lng        country         state  population_x  \
# 0      New York  40.6943  -73.9249  United States      New York    18908608.0
# 1       Chicago  41.8375  -87.6866  United States      Illinois     8497759.0
# 2         Miami  25.7840  -80.2101  United States       Florida     6080145.0
# 3       Houston  29.7860  -95.3885  United States         Texas     5970127.0
# 4        Dallas  32.7935  -96.7667  United States         Texas     5830932.0
# ...         ...      ...       ...            ...           ...           ...
# 3356    Delavan  42.6282  -88.6323  United States     Wisconsin        8519.0
# 3357  Evergreen  48.2308 -114.2700  United States       Montana        8514.0
# 3358  Sutherlin  43.3882 -123.3242  United States        Oregon        8513.0
# 3359    Altoona  44.8029  -91.4385  United States     Wisconsin        8506.0
# 3360  Old Forge  41.3704  -75.7409  United States  Pennsylvania        8506.0
#
#       greenspacearea_km2  obesity_rate  smoking_rate  exercising_rate  \
# 0                   9.58          30.1          11.5             50.7
# 1                   0.29          33.4          12.8             50.0
# 2                  35.57          31.6          12.0             54.3
# 3                  52.57          35.5          12.0             49.4
# 4                  79.91          35.5          12.0             49.4
# ...                  ...           ...           ...              ...
# 3356               17.37          37.7          15.0             55.0
# 3357                0.96          30.5          16.0             63.2
# 3358               54.94          30.9          12.8             56.8
# 3359                0.27          37.7          15.0             55.0
# 3360               36.90          33.4          15.6             50.8
#
#       chronic_rate  life_expectancy  population_y  adjusted_obesity_rate  \
# 0             15.7             77.7      19571216              29.080927
# 1             15.6             76.8      12549689              22.616110
# 2             16.5             77.5      22610726               8.497409
# 3             16.6             76.5      30503301               6.948084
# 4             16.6             76.5      30503301               6.786088
# ...            ...              ...           ...                    ...
# 3356          17.0             77.7       5910955               0.054334
# 3357          16.4             76.8       1132812               0.229232
# 3358          17.4             78.8       4233358               0.062138
# 3359          17.0             77.7       5910955               0.054251
# 3360          18.5             76.8      12961683               0.021918
#
#       adjusted_smoking_rate  adjusted_exercising_rate  adjusted_chronic_rate  \
# 0                 11.110653                 48.983488              15.168457
# 1                  8.667252                 33.856453              10.563213
# 2                  3.226864                 14.601560               4.436938
# 3                  2.348648                  9.668602               3.248963
# 4                  2.293889                  9.443176               3.173213
# ...                     ...                       ...                    ...
# 3356               0.021618                  0.079267               0.024501
# 3357               0.120253                  0.474999               0.123259
# 3358               0.025740                  0.114221               0.034990
# 3359               0.021585                  0.079146               0.024463
# 3360               0.010237                  0.033337               0.012140
#
#       adjusted_life_expectancy
# 0                    75.069369
# 1                    52.003511
# 2                    20.840164
# 3                    14.972632
# 4                    14.623542
# ...                        ...
# 3356                  0.111983
# 3357                  0.577214
# 3358                  0.158462
# 3359                  0.111812
# 3360                  0.050399
#
# [3361 rows x 18 columns]

# %%
print("data_cleaned_merged shape:", data_cleaned_merged.shape)
print("merged_final_df shape:", merged_final_df.shape)

# Ensure city columns are consistent
print("Cities in data_cleaned_merged not in merged_final_df:", 
      set(data_cleaned_merged['city']) - set(merged_final_df['city']))

print("Cities in merged_final_df not in data_cleaned_merged:", 
      set(merged_final_df['city']) - set(data_cleaned_merged['city']))
# Out:
# data_cleaned_merged shape: (3361, 19)
# merged_final_df shape: (3361, 22)
# Cities in data_cleaned_merged not in merged_final_df: set()
# Cities in merged_final_df not in data_cleaned_merged: set()

# %%
# Step 1: Ensure 'city' is unique in merged_final_df
# (Even though you've already mentioned there are no duplicates, this is a double-check)
merged_final_df_unique = merged_final_df[['city', 'adjusted_copd_rate', 'adjusted_depression_rate']].drop_duplicates(subset='city')

# Step 2: Perform the merge operation
data_for_fe = data_cleaned_merged.merge(
    merged_final_df_unique,  # Only the 'city' column and the two columns you need
    on='city',  # Merge on 'city'
    how='left'  # Left join, keeping all rows from data_cleaned_merged
)

# Step 3: Verify the merge result
print("Shape after merge:", data_for_fe.shape)
print(data_for_fe.head())
# Out:
# Shape after merge: (3361, 21)
#        city      lat      lng        country     state  population_city  \
# 0  New York  40.6943 -73.9249  United States  New York       18908608.0
# 1   Chicago  41.8375 -87.6866  United States  Illinois        8497759.0
# 2     Miami  25.7840 -80.2101  United States   Florida        6080145.0
# 3   Houston  29.7860 -95.3885  United States     Texas        5970127.0
# 4    Dallas  32.7935 -96.7667  United States     Texas        5830932.0
#
#    greenspacearea_km2  obesity_rate  smoking_rate  exercising_rate  ...  \
# 0                9.58          30.1          11.5             50.7  ...
# 1                0.29          33.4          12.8             50.0  ...
# 2               35.57          31.6          12.0             54.3  ...
# 3               52.57          35.5          12.0             49.4  ...
# 4               79.91          35.5          12.0             49.4  ...
#
#    life_expectancy  population_state  adjusted_obesity_rate  \
# 0             77.7          19571216              29.080927
# 1             76.8          12549689              22.616110
# 2             77.5          22610726               8.497409
# 3             76.5          30503301               6.948084
# 4             76.5          30503301               6.786088
#
#    adjusted_smoking_rate  adjusted_exercising_rate  adjusted_chronic_rate  \
# 0              11.110653                 48.983488              15.168457
# 1               8.667252                 33.856453              10.563213
# 2               3.226864                 14.601560               4.436938
# 3               2.348648                  9.668602               3.248963
# 4               2.293889                  9.443176               3.173213
#
#    adjusted_life_expectancy       AQI  adjusted_copd_rate  \
# 0                 75.069369  2.013333            4.444261
# 1                 52.003511  1.930196            3.521071
# 2                 20.840164  1.639216            1.667213
# 3                 14.972632  1.789020            1.096036
# 4                 14.623542  1.880000           29.295229
#
#    adjusted_depression_rate
# 0                 17.487202
# 1                 12.188323
# 2                  4.920968
# 3                  3.796981
# 4                101.487042
#
# [5 rows x 21 columns]

# %%
data_for_fe
# Out:
#            city      lat       lng        country         state  \
# 0      New York  40.6943  -73.9249  United States      New York
# 1       Chicago  41.8375  -87.6866  United States      Illinois
# 2         Miami  25.7840  -80.2101  United States       Florida
# 3       Houston  29.7860  -95.3885  United States         Texas
# 4        Dallas  32.7935  -96.7667  United States         Texas
# ...         ...      ...       ...            ...           ...
# 3356    Delavan  42.6282  -88.6323  United States     Wisconsin
# 3357  Evergreen  48.2308 -114.2700  United States       Montana
# 3358  Sutherlin  43.3882 -123.3242  United States        Oregon
# 3359    Altoona  44.8029  -91.4385  United States     Wisconsin
# 3360  Old Forge  41.3704  -75.7409  United States  Pennsylvania
#
#       population_city  greenspacearea_km2  obesity_rate  smoking_rate  \
# 0          18908608.0                9.58          30.1          11.5
# 1           8497759.0                0.29          33.4          12.8
# 2           6080145.0               35.57          31.6          12.0
# 3           5970127.0               52.57          35.5          12.0
# 4           5830932.0               79.91          35.5          12.0
# ...               ...                 ...           ...           ...
# 3356           8519.0               17.37          37.7          15.0
# 3357           8514.0                0.96          30.5          16.0
# 3358           8513.0               54.94          30.9          12.8
# 3359           8506.0                0.27          37.7          15.0
# 3360           8506.0               36.90          33.4          15.6
#
#       exercising_rate  ...  life_expectancy  population_state  \
# 0                50.7  ...             77.7          19571216
# 1                50.0  ...             76.8          12549689
# 2                54.3  ...             77.5          22610726
# 3                49.4  ...             76.5          30503301
# 4                49.4  ...             76.5          30503301
# ...               ...  ...              ...               ...
# 3356             55.0  ...             77.7           5910955
# 3357             63.2  ...             76.8           1132812
# 3358             56.8  ...             78.8           4233358
# 3359             55.0  ...             77.7           5910955
# 3360             50.8  ...             76.8          12961683
#
#       adjusted_obesity_rate  adjusted_smoking_rate  adjusted_exercising_rate  \
# 0                 29.080927              11.110653                 48.983488
# 1                 22.616110               8.667252                 33.856453
# 2                  8.497409               3.226864                 14.601560
# 3                  6.948084               2.348648                  9.668602
# 4                  6.786088               2.293889                  9.443176
# ...                     ...                    ...                       ...
# 3356               0.054334               0.021618                  0.079267
# 3357               0.229232               0.120253                  0.474999
# 3358               0.062138               0.025740                  0.114221
# 3359               0.054251               0.021585                  0.079146
# 3360               0.021918               0.010237                  0.033337
#
#       adjusted_chronic_rate  adjusted_life_expectancy       AQI  \
# 0                 15.168457                 75.069369  2.013333
# 1                 10.563213                 52.003511  1.930196
# 2                  4.436938                 20.840164  1.639216
# 3                  3.248963                 14.972632  1.789020
# 4                  3.173213                 14.623542  1.880000
# ...                     ...                       ...       ...
# 3356               0.024501                  0.111983  1.854902
# 3357               0.123259                  0.577214  1.510588
# 3358               0.034990                  0.158462  1.381176
# 3359               0.024463                  0.111812  1.692549
# 3360               0.012140                  0.050399       NaN
#
#       adjusted_copd_rate  adjusted_depression_rate
# 0               4.444261                 17.487202
# 1               3.521071                 12.188323
# 2               1.667213                  4.920968
# 3               1.096036                  3.796981
# 4              29.295229                101.487042
# ...                  ...                       ...
# 3356            0.008359                  0.034878
# 3357            0.007480                  0.033277
# 3358            0.011663                  0.049871
# 3359            0.036839                  0.124472
# 3360            0.004331                  0.014634
#
# [3361 rows x 21 columns]

# %%
# Checking for duplicates and missing values

data_for_fe.duplicated().sum()
# Out:
# 0

# %%
export_csv = data_for_fe.to_csv('/Users/alexandreribeiro/Documents/GitHub/final_project/notebooks/final_dataset.csv', index=False)
